# %% [markdown]
# # Training hindi alphabets recognition model
#
#
# This notebook allows to train hindi alphabets generated through https://tinymlx.org/magic_wand/ using Arduino BLE 33 Sense to build a TensorFlow lite Model.

# %% [markdown]
# ### Import Packages and Set Constants

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from google.colab import files
from IPython.display import Image, display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import shutil
import PIL
import math
import glob
import json
import os
# !apt-get update && apt-get -qq install xxd
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Ign:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [634 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [473 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,418 kB]
# Get:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,221 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,779 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [506 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,657 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [910 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,188 kB]
# Get:25 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [40.8 kB]
# Get:26 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [41.5 kB]
# Fetched 13.2 MB in 5s (2,677 kB/s)
# Reading package lists... Done
# Selecting previously unselected package xxd.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../xxd_2%3a8.0.1453-1ubuntu1.4_amd64.deb ...
# Unpacking xxd (2:8.0.1453-1ubuntu1.4) ...
# Setting up xxd (2:8.0.1453-1ubuntu1.4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# Define filenames and set up directory structure
MODELS_DIR = 'models'
if not os.path.exists(MODELS_DIR):
  os.mkdir(MODELS_DIR)
SAVED_MODEL_FILENAME = os.path.join(MODELS_DIR, "hindi_alphabets")
FLOAT_TFL_MODEL_FILENAME = os.path.join(MODELS_DIR, "hindi_alphabets_float.tfl")
QUANTIZED_TFL_MODEL_FILENAME = os.path.join(MODELS_DIR, "hindi_alphabets.tfl")
TFL_CC_MODEL_FILENAME = os.path.join(MODELS_DIR, "hindi_alphabets.cc")

DATASET_DIR =  'hindi_alphabets_dataset'
if not os.path.exists(DATASET_DIR):
  os.mkdir(DATASET_DIR)
TRAIN_DIR = os.path.join(DATASET_DIR, "train")
VAL_DIR = os.path.join(DATASET_DIR, "validation")
TEST_DIR = os.path.join(DATASET_DIR, "test")
# !rm -rf sample_data

CHKPT_DIR =  'checkpoints'
if not os.path.exists(CHKPT_DIR):
  os.mkdir(CHKPT_DIR)

# Train Split
TEST_PERCENTAGE = 10
VALIDATION_PERCENTAGE = 10
TRAIN_PERCENTAGE = 100 - (TEST_PERCENTAGE + VALIDATION_PERCENTAGE)

# %% [markdown]
# ### Load Your Custom Dataset
# Now you'll need to upload all of your hindi alphabets files that you created using the Arduino Nano 33 BLE Sense  (aka the ```*.json``` files). **Note: you can select multiple files and upload them all at once!**
#
# If you are having trouble uploading files because your internet bandwidth is too slow feel free to uncomment the lines below to instead use Pete's digits dataset.

# %%
# Upload your files
os.chdir("/content/hindi_alphabets_dataset")
uploaded = files.upload()
os.chdir("/content")
# Out:
#      <input type="file" id="files-816f1f0b-7a6e-4c72-b3cc-e266db8910af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-816f1f0b-7a6e-4c72-b3cc-e266db8910af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hindi_alphabet_e_133_1.json to hindi_alphabet_e_133_1.json
# Saving hindi_alphabet_e_165_0.json to hindi_alphabet_e_165_0.json
# Saving hindi_alphabet_k_86_0.json to hindi_alphabet_k_86_0.json
# Saving hindi_alphabet_k_169_1.json to hindi_alphabet_k_169_1.json
# Saving hindi_alphabet_n_130_0.json to hindi_alphabet_n_130_0.json
# Saving hindi_alphabet_n_133_1.json to hindi_alphabet_n_133_1.json
# Saving hindi_alphabet_p_127_0.json to hindi_alphabet_p_127_0.json
# Saving hindi_alphabet_p_168_1.json to hindi_alphabet_p_168_1.json
# Saving hindi_alphabet_t_138_1.json to hindi_alphabet_t_138_1.json
# Saving hindi_alphabet_t_166_0.json to hindi_alphabet_t_166_0.json

# %% [markdown]
# **Update the variable below with the number of labeled gestures in your dataset**
# Note: Use the number of unique gestures/labels and *not* the number of samples in your dataset.

# %%
NUM_GESTURES = 5 # UPDATE THIS WITH THE NUMBER OF UNIQUE GESTURES IN YOUR DATASET #

# %% [markdown]
# Next we'll parse the JSON files into a python object which we can more easily work with.

# %%
dataset_jsons = DATASET_DIR + "/*.json"
strokes = []
for filename in glob.glob(dataset_jsons):
  with open(filename, "r") as file:
    file_contents = file.read()
  file_data = json.loads(file_contents)
  for stroke in file_data["strokes"]:
    stroke["filename"] = filename
    strokes.append(stroke)

# %% [markdown]
# If you'd like to visualize any of your gestures you can use the helper function below!

# %%
# Helper function to visualize the data
def plot_stroke(stroke):
  x_array = []
  y_array = []
  for coords in stroke["strokePoints"]:
    x_array.append(coords["x"])
    y_array.append(coords["y"])

  fig = plt.figure(figsize=(12.8, 4.8))
  fig.suptitle(stroke["label"])

  ax = fig.add_subplot(131)
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_xlim(-0.4, 0.4)
  ax.set_ylim(-0.4, 0.4)
  ax.plot(x_array, y_array)

  plt.show()

# %%
# Display a stroke from the strokes python variable
plot_stroke(strokes[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### Preprocess your Dataset
# Next we'll preprocess the dataset to prepare it for training. By preprocessing the data in bulk before training the whole training process will execute much faster. To do so, we'll convert the strokes into rastered images using the helper functions below. This is the process used in real-time in the Arduino code to convert a gesture into an image that the CNN we are going to train can then process.
#
# Once we have converted the dataset to rasterized images we will generate a ```Keras``` dataset for use in training.

# %%
FIXED_POINT = 256

def mul_fp(a, b):
  return (a * b) / FIXED_POINT

def div_fp(a, b):
  if b == 0:
    b = 1
  return (a * FIXED_POINT) / b

def float_to_fp(a):
  return math.floor(a * FIXED_POINT)

def norm_to_coord_fp(a, range_fp, half_size_fp):
  a_fp = float_to_fp(a)
  norm_fp = div_fp(a_fp, range_fp)
  return mul_fp(norm_fp, half_size_fp) + half_size_fp

def round_fp_to_int(a):
  return math.floor((a + (FIXED_POINT / 2)) / FIXED_POINT)

def gate(a, min, max):
  if a < min:
    return min
  elif a > max:
    return max
  else:
    return a

def rasterize_stroke(stroke_points, x_range, y_range, width, height):
  num_channels = 3
  buffer_byte_count = height * width * num_channels
  buffer = bytearray(buffer_byte_count)

  width_fp = width * FIXED_POINT
  height_fp = height * FIXED_POINT
  half_width_fp = width_fp / 2
  half_height_fp = height_fp / 2
  x_range_fp = float_to_fp(x_range)
  y_range_fp = float_to_fp(y_range)

  t_inc_fp = FIXED_POINT / len(stroke_points)

  one_half_fp = (FIXED_POINT / 2)

  for point_index in range(len(stroke_points) - 1):
    start_point = stroke_points[point_index]
    end_point = stroke_points[point_index + 1]
    start_x_fp = norm_to_coord_fp(start_point["x"], x_range_fp, half_width_fp)
    start_y_fp = norm_to_coord_fp(-start_point["y"], y_range_fp, half_height_fp)
    end_x_fp = norm_to_coord_fp(end_point["x"], x_range_fp, half_width_fp)
    end_y_fp = norm_to_coord_fp(-end_point["y"], y_range_fp, half_height_fp)
    delta_x_fp = end_x_fp - start_x_fp
    delta_y_fp = end_y_fp - start_y_fp

    t_fp = point_index * t_inc_fp
    if t_fp < one_half_fp:
      local_t_fp = div_fp(t_fp, one_half_fp)
      one_minus_t_fp = FIXED_POINT - local_t_fp
      red = round_fp_to_int(one_minus_t_fp * 255)
      green = round_fp_to_int(local_t_fp * 255)
      blue = 0
    else:
      local_t_fp = div_fp(t_fp - one_half_fp, one_half_fp)
      one_minus_t_fp = FIXED_POINT - local_t_fp
      red = 0
      green = round_fp_to_int(one_minus_t_fp * 255)
      blue = round_fp_to_int(local_t_fp * 255)
    red = gate(red, 0, 255)
    green = gate(green, 0, 255)
    blue = gate(blue, 0, 255)

    if abs(delta_x_fp) > abs(delta_y_fp):
      line_length = abs(round_fp_to_int(delta_x_fp))
      if delta_x_fp > 0:
        x_inc_fp = 1 * FIXED_POINT
        y_inc_fp = div_fp(delta_y_fp, delta_x_fp)
      else:
        x_inc_fp = -1 * FIXED_POINT
        y_inc_fp = -div_fp(delta_y_fp, delta_x_fp)
    else:
      line_length = abs(round_fp_to_int(delta_y_fp))
      if delta_y_fp > 0:
        y_inc_fp = 1 * FIXED_POINT
        x_inc_fp = div_fp(delta_x_fp, delta_y_fp)
      else:
        y_inc_fp = -1 * FIXED_POINT
        x_inc_fp = -div_fp(delta_x_fp, delta_y_fp)
    for i in range(line_length + 1):
      x_fp = start_x_fp + (i * x_inc_fp)
      y_fp = start_y_fp + (i * y_inc_fp)
      x = round_fp_to_int(x_fp)
      y = round_fp_to_int(y_fp)
      if (x < 0) or (x >= width) or (y < 0) or (y >= height):
        continue
      buffer_index = (y * width * num_channels) + (x * num_channels)
      buffer[buffer_index + 0] = red
      buffer[buffer_index + 1] = green
      buffer[buffer_index + 2] = blue
  
  np_buffer = np.frombuffer(buffer, dtype=np.uint8).reshape(height, width, num_channels)

  return np_buffer

# %%
X_RANGE = 0.6
Y_RANGE = 0.6

def ensure_empty_dir(dirname):
  dirpath = Path(dirname)
  if dirpath.exists() and dirpath.is_dir():
    shutil.rmtree(dirpath)
  dirpath.mkdir()

def augment_points(points, move_range, scale_range, rotate_range):
  move_x = np.random.uniform(low=-move_range, high=move_range)
  move_y = np.random.uniform(low=-move_range, high=move_range)
  scale = np.random.uniform(low=1.0-scale_range, high=1.0+scale_range)
  rotate = np.random.uniform(low=-rotate_range, high=rotate_range)

  x_axis_x = math.cos(rotate) * scale
  x_axis_y = math.sin(rotate) * scale

  y_axis_x = -math.sin(rotate) * scale
  y_axis_y = math.cos(rotate) * scale

  new_points = []
  for point in points:
    old_x = point["x"]
    old_y = point["y"]
    new_x = (x_axis_x * old_x) + (x_axis_y * old_y) + move_x
    new_y = (y_axis_x * old_x) + (y_axis_y * old_y) + move_y
    new_points.append({"x": new_x, "y": new_y})

  return new_points

def save_strokes_as_images(strokes, root_folder, width, height, augment_count):
  ensure_empty_dir(root_folder)
  labels = set()
  for stroke in strokes:
    labels.add(stroke["label"].lower())
  for label in labels:
    label_path = Path(root_folder, label)
    ensure_empty_dir(label_path)

  label_counts = {}
  for stroke in strokes:
    points = stroke["strokePoints"]
    label = stroke["label"].lower()
    if label == "":
      raise Exception("Missing label for %s:%d" % (stroke["filename"], stroke["index"]))
    if label not in label_counts:
      label_counts[label] = 0
    label_count = label_counts[label]
    label_counts[label] += 1
    raster = rasterize_stroke(points, X_RANGE, Y_RANGE, width, height)
    image = PIL.Image.fromarray(raster)
    image.save(Path(root_folder, label, str(label_count) + ".png"))
    for i in range(augment_count):
      augmented_points = augment_points(points, 0.1, 0.1, 0.3)
      raster = rasterize_stroke(augmented_points, X_RANGE, Y_RANGE, width, height)
      image = PIL.Image.fromarray(raster)
      image.save(Path(root_folder, label, str(label_count) + "_a" + str(i) + ".png"))
  return labels

# %% [markdown]
# Take the dataset and shuffle it into the Training/Validation/Test splits

# %%
IMAGE_WIDTH = 32
IMAGE_HEIGHT = 32

shuffled_strokes = strokes
np.random.shuffle(shuffled_strokes)

test_count = math.floor((len(shuffled_strokes) * TEST_PERCENTAGE) / 100)
validation_count = math.floor((len(shuffled_strokes) * VALIDATION_PERCENTAGE) / 100)
test_strokes = shuffled_strokes[0:test_count]
validation_strokes = shuffled_strokes[test_count:(test_count + validation_count)]
train_strokes = shuffled_strokes[(test_count + validation_count):]

labels_test  = save_strokes_as_images(test_strokes, TEST_DIR, IMAGE_WIDTH, IMAGE_HEIGHT, 10)
labels_val   = save_strokes_as_images(validation_strokes, VAL_DIR, IMAGE_WIDTH, IMAGE_HEIGHT, 0)
labels_train = save_strokes_as_images(train_strokes, TRAIN_DIR, IMAGE_WIDTH, IMAGE_HEIGHT, 10)

# %% [markdown]
# Also get the alphanumeric ordering of the labels as the Neural Network will output its result in this order for the predicted class. **Make a note of this ordering as you will need to enter the labels in order in the Arduino code!**

# %%
labels = sorted(labels_test.union(labels_val).union(labels_train))
# get the conversion from label string to int
labelToInt = {}
currInt = 0
for label in labels:
  labelToInt[label] = currInt
  currInt = currInt + 1
intToLabel = {v: k for k, v in labelToInt.items()}
print(intToLabel)
# Out:
# {0: 'इ', 1: 'क', 2: 'ट', 3: 'न', 4: 'प'}

# %% [markdown]
# If you'd like to visualize the difference between a stroke and its rasterized output image, run the cell below!

# %%
plot_stroke(strokes[0])
raster = rasterize_stroke(strokes[0]["strokePoints"], 0.5, 0.5, 32, 32)
PIL.Image.fromarray(raster).resize((512, 512), PIL.Image.NEAREST)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2346 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2346 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F66A9E51F90>

# %% [markdown]
# Finally, we'll generate a dataset in ```Keras```.

# %%
validation_ds = image_dataset_from_directory(
    directory=VAL_DIR,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(IMAGE_WIDTH, IMAGE_HEIGHT)).prefetch(buffer_size=32)

train_ds = image_dataset_from_directory(
    directory=TRAIN_DIR,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(IMAGE_WIDTH, IMAGE_HEIGHT)).prefetch(buffer_size=32)
# Out:
# Found 141 files belonging to 5 classes.
# Found 12463 files belonging to 5 classes.

# %%
# Plot 9 of our final dataset items
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## Define your Model
#
# Next we will define and visualize the CNN model that we will use for the hindi alphabets recognition

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(16, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.5)(x)

    x = layers.GlobalAveragePooling2D()(x)
    activation = "softmax"
    units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

model = make_model(input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3), num_classes=NUM_GESTURES)

# %%
# View the model layers as a diagram
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Train your Model
#
# Now that we have a preprocessed dataset and a model its time to train that model with that dataset!

# %%
# How many epochs to train for, we have found ~30 to be a good starting point
EPOCHS = 30

# Callback to save model checkpoints for future inspection or training
checkpointFileLoc = CHKPT_DIR + "/save_at_{epoch:02d}.h5"
modelCheckpointCallback = keras.callbacks.ModelCheckpoint(checkpointFileLoc)

# Compile the model!
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

# Run training
history = model.fit(train_ds, epochs=EPOCHS, validation_data=validation_ds,
                    callbacks=[modelCheckpointCallback])
# Out:
# Epoch 1/30
# 390/390 [==============================] - 11s 25ms/step - loss: 0.5000 - accuracy: 0.3158 - val_loss: 0.4986 - val_accuracy: 0.2128
# Epoch 2/30
# 390/390 [==============================] - 10s 26ms/step - loss: 0.4033 - accuracy: 0.5343 - val_loss: 0.3158 - val_accuracy: 0.5674
# Epoch 3/30
# 390/390 [==============================] - 10s 27ms/step - loss: 0.3192 - accuracy: 0.6853 - val_loss: 0.1976 - val_accuracy: 0.8723
# Epoch 4/30
# 390/390 [==============================] - 10s 26ms/step - loss: 0.2720 - accuracy: 0.7437 - val_loss: 0.4633 - val_accuracy: 0.4681
# Epoch 5/30
# 390/390 [==============================] - 10s 26ms/step - loss: 0.2365 - accuracy: 0.7899 - val_loss: 0.1259 - val_accuracy: 0.9574
# Epoch 6/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.2070 - accuracy: 0.8262 - val_loss: 0.0909 - val_accuracy: 0.9645
# Epoch 7/30
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1836 - accuracy: 0.8525 - val_loss: 0.1124 - val_accuracy: 0.9149
# Epoch 8/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1691 - accuracy: 0.8654 - val_loss: 0.3402 - val_accuracy: 0.5319
# Epoch 9/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1568 - accuracy: 0.8804 - val_loss: 0.0521 - val_accuracy: 0.9716
# Epoch 10/30
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1483 - accuracy: 0.8872 - val_loss: 0.0415 - val_accuracy: 0.9929
# Epoch 11/30
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1397 - accuracy: 0.8970 - val_loss: 0.0410 - val_accuracy: 0.9929
# Epoch 12/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1328 - accuracy: 0.9048 - val_loss: 0.0462 - val_accuracy: 0.9645
# Epoch 13/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1291 - accuracy: 0.9026 - val_loss: 0.0343 - val_accuracy: 0.9858
# Epoch 14/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1266 - accuracy: 0.9087 - val_loss: 0.0313 - val_accuracy: 0.9787
# Epoch 15/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1201 - accuracy: 0.9168 - val_loss: 0.0325 - val_accuracy: 0.9787
# Epoch 16/30
# 390/390 [==============================] - 11s 29ms/step - loss: 0.1218 - accuracy: 0.9121 - val_loss: 0.0340 - val_accuracy: 0.9858
# Epoch 17/30
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1125 - accuracy: 0.9190 - val_loss: 0.0256 - val_accuracy: 0.9929
# Epoch 18/30
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1123 - accuracy: 0.9220 - val_loss: 0.0294 - val_accuracy: 0.9858
# Epoch 19/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1122 - accuracy: 0.9212 - val_loss: 0.0341 - val_accuracy: 0.9858
# Epoch 20/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1056 - accuracy: 0.9264 - val_loss: 0.0241 - val_accuracy: 0.9858
# Epoch 21/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1031 - accuracy: 0.9279 - val_loss: 0.0231 - val_accuracy: 0.9929
# Epoch 22/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.1015 - accuracy: 0.9319 - val_loss: 0.0215 - val_accuracy: 0.9929
# Epoch 23/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0995 - accuracy: 0.9315 - val_loss: 0.0222 - val_accuracy: 0.9858
# Epoch 24/30
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0971 - accuracy: 0.9334 - val_loss: 0.0228 - val_accuracy: 0.9929
# Epoch 25/30
# 390/390 [==============================] - 11s 29ms/step - loss: 0.0976 - accuracy: 0.9316 - val_loss: 0.0216 - val_accuracy: 0.9929
# Epoch 26/30
# 390/390 [==============================] - 12s 30ms/step - loss: 0.0981 - accuracy: 0.9307 - val_loss: 0.0198 - val_accuracy: 0.9929
# Epoch 27/30
# 390/390 [==============================] - 13s 34ms/step - loss: 0.0924 - accuracy: 0.9375 - val_loss: 0.0343 - val_accuracy: 0.9645
# Epoch 28/30
# 390/390 [==============================] - 13s 33ms/step - loss: 0.0984 - accuracy: 0.9330 - val_loss: 0.0244 - val_accuracy: 0.9929
# Epoch 29/30
# 390/390 [==============================] - 13s 32ms/step - loss: 0.0908 - accuracy: 0.9377 - val_loss: 0.2850 - val_accuracy: 0.6738
# Epoch 30/30
# 390/390 [==============================] - 13s 33ms/step - loss: 0.0907 - accuracy: 0.9369 - val_loss: 0.0159 - val_accuracy: 0.9929

# %%
# save the model file
model.save(SAVED_MODEL_FILENAME)
# Out:
# INFO:tensorflow:Assets written to: models/hindi_alphabets/assets

# %% [markdown]
# ## Test your TensorFlow Model
#
# Lets now test out the TF model on the test dataset. We'll print out any gesture we get wrong as well as the percentage of known gestures correct as well as the number of gestures that were marked as unknown.

# %%
SCORE_THRESHOLD = 0.75 # Confidence threshold to discard an image as "unknown"

def predict_image(model, filename):
  img = keras.preprocessing.image.load_img(filename, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
  img_array = keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0)  # Create batch axis
  predictions = model.predict(img_array).flatten()
  predicted_label_index = np.argmax(predictions)
  predicted_score = predictions[predicted_label_index]
  return (predicted_label_index, predicted_score)

correct_count = 0
wrong_count = 0
discarded_count = 0
for label_dir in glob.glob(TEST_DIR + "/*"):
  label = label_dir.replace(TEST_DIR + "/", "")
  print("Testing Gesture: ",label," with datasize: ",len(glob.glob(label_dir + "/*.png")))
  for filename in glob.glob(label_dir + "/*.png"):
    index, score = predict_image(model, filename)
    if score < SCORE_THRESHOLD:
      discarded_count += 1
      continue
    if index == labelToInt[label]:
      correct_count += 1
    else:
      wrong_count += 1
      print(label,index,score)
      print("[%s] expected, [%s] found with score [%f]" % (label, intToLabel[index], score))
      display(Image(filename=filename))

if correct_count + wrong_count == 0:
  print("All images marked as unknown!")
else:
  correct_percentage = (correct_count / (correct_count + wrong_count)) * 100
  print("%.1f%% correct (N=%d, %d unknown)" % (correct_percentage, (correct_count + wrong_count), discarded_count))
# Out:
# Testing Gesture:  इ  with datasize:  385
# Testing Gesture:  क  with datasize:  297
# Testing Gesture:  न  with datasize:  264
# Testing Gesture:  ट  with datasize:  341
# Testing Gesture:  प  with datasize:  264
# 100.0% correct (N=1540, 11 unknown)

# %% [markdown]
# If you'd like to manually evaluate particular images you can uncomment, update, and run the below cell and select an image from the test folder.

# %%
# TEST_IMAGE = # UPDATE ME e.g., "test/0/1.png"
# index, score = predict_image(model, TEST_IMAGE)
# print(index, score) # prints the guessed index and the confidence

# %% [markdown]
# ## Generate a TensorFlow Lite Model
#
# Convert the frozen graph into a TensorFlow Lite model, which is fully quantized for use with embedded devices. The following cell will also print the model size.

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL_FILENAME)
model_no_quant_tflite = converter.convert()

# Save the model to disk
open(FLOAT_TFL_MODEL_FILENAME, "wb").write(model_no_quant_tflite)

def representative_dataset():
  for filename in glob.glob(TEST_DIR + "/*/*.png"):
    img = keras.preprocessing.image.load_img(filename, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis for images, labels in train_ds.take(1):
    yield([img_array])
# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(QUANTIZED_TFL_MODEL_FILENAME, "wb").write(model_tflite)
# Out:
# 30360

# %% [markdown]
# Compare the sizes of the Tensorflow, TensorFlow Lite and Quantized TensorFlow Lite models.

# %%
def get_dir_size(dir):
  size = 0
  for f in os.scandir(dir):
    if f.is_file():
      size += f.stat().st_size
    elif f.is_dir():
      size += get_dir_size(f.path)
  return size

# Calculate size
size_tf = get_dir_size(SAVED_MODEL_FILENAME)
size_no_quant_tflite = os.path.getsize(FLOAT_TFL_MODEL_FILENAME)
size_tflite = os.path.getsize(QUANTIZED_TFL_MODEL_FILENAME)

# Compare size
pd.DataFrame.from_records(
    [["TensorFlow", f"{size_tf} bytes", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite} bytes ", f"(reduced by {size_tf - size_no_quant_tflite} bytes)"],
     ["TensorFlow Lite Quantized", f"{size_tflite} bytes", f"(reduced by {size_no_quant_tflite - size_tflite} bytes)"]],
     columns = ["Model", "Size", ""], index="Model")
# Out:
#                                    Size
# Model
# TensorFlow                 698420 bytes
# TensorFlow Lite            98732 bytes   (reduced by 599688 bytes)
# TensorFlow Lite Quantized   30360 bytes   (reduced by 68372 bytes)

# %% [markdown]
# ## Test your TensorFlow Lite Models
#
# Lets now test out the TFLite models (quantized and unquantized) on the test dataset. We'll print out any gesture we get wrong as well as the percentage of known gestures correct as well as the number of gestures that were marked as unknown.

# %%
def predict_tflite(tflite_model, filename):
  img = keras.preprocessing.image.load_img(filename, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
  img_array = keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0)

  # Initialize the TFLite interpreter
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # If required, quantize the input layer (from float to integer)
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    img_array = np.multiply(img_array, 1.0 / input_scale) + input_zero_point
    img_array = img_array.astype(input_details["dtype"])
  
  # Invoke the interpreter
  interpreter.set_tensor(input_details["index"], img_array)
  interpreter.invoke()
  pred = interpreter.get_tensor(output_details["index"])[0]
  
  # If required, dequantized the output layer (from integer to float)
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    pred = pred.astype(np.float32)
    pred = np.multiply((pred - output_zero_point), output_scale)
  
  predicted_label_index = np.argmax(pred)
  predicted_score = pred[predicted_label_index]
  return (predicted_label_index, predicted_score)

# %%
def run_tflite_test(model_file):
  correct_count = 0
  wrong_count = 0
  discarded_count = 0
  for label_dir in glob.glob(TEST_DIR + "/*"):
    label = label_dir.replace(TEST_DIR + "/", "")
    print("Testing Gesture: ",label," with datasize: ",len(glob.glob(label_dir + "/*.png")))
    for filename in glob.glob(label_dir + "/*.png"):
      index, score = predict_tflite(model_file, filename)
      if score < 0.75:
        discarded_count += 1
        continue
      if index == labelToInt[label]:
        correct_count += 1
      else:
        wrong_count += 1
        print("[%s] expected, [%s] found with score [%f]" % (label, intToLabel[index], score))
        display(Image(filename=filename))

  correct_percentage = (correct_count / (correct_count + wrong_count)) * 100

  print("%.1f%% correct (N=%d, %d unknown)" % (correct_percentage, (correct_count + wrong_count), discarded_count))

# %% [markdown]
# First test the float model.

# %%
run_tflite_test(model_no_quant_tflite)
# Out:
# Testing Gesture:  इ  with datasize:  385
# Testing Gesture:  क  with datasize:  297
# Testing Gesture:  न  with datasize:  264
# Testing Gesture:  ट  with datasize:  341
# Testing Gesture:  प  with datasize:  264
# 100.0% correct (N=1540, 11 unknown)

# %% [markdown]
# Then test the quantized model

# %%
run_tflite_test(model_tflite)
# Out:
# Testing Gesture:  इ  with datasize:  385
# Testing Gesture:  क  with datasize:  297
# Testing Gesture:  न  with datasize:  264
# Testing Gesture:  ट  with datasize:  341
# Testing Gesture:  प  with datasize:  264
# 100.0% correct (N=1540, 11 unknown)

# %% [markdown]
# If you'd like to manually evaluate particular images you can uncomment, update, and run the below cell and select an image from the test folder.

# %%
# TEST_IMAGE = # UPDATE ME e.g., "test/0/1.png"
# index, score = predict_tflite(model_no_quant_tflite, TEST_IMAGE)
# print("Float model result:")
# print(index, score) # prints the guessed index and the confidence
# index, score = predict_tflite(model_tflite, TEST_IMAGE)
# print("Quantized model result:")
# print(index, score) # prints the guessed index and the confidence

# %% [markdown]
# ## Generate a TensorFlow Lite for Microcontrollers Model
# To convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite for Microcontrollers on Arduino we simply need to use the ```xxd``` tool to convert the ```.tflite``` file into a ```.cc``` file.

# %%
# Convert to a C source file, i.e, a TensorFlow Lite for Microcontrollers model
# !xxd -i {QUANTIZED_TFL_MODEL_FILENAME} > {TFL_CC_MODEL_FILENAME}
# Update variable names
REPLACE_TEXT = QUANTIZED_TFL_MODEL_FILENAME.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_hindi_alphabets_model_data/g' {TFL_CC_MODEL_FILENAME}

# %% [markdown]
# That's it! You've successfully converted your TensorFlow Lite model into a TensorFlow Lite for Microcontrollers model! Run the cell below to print out its contents which we'll need for our next step, deploying the model using the Arudino IDE!

# %%
# Print the C source file
# !cat {TFL_CC_MODEL_FILENAME}
# !tail {TFL_CC_MODEL_FILENAME} # run this command to just see the end of the file (aka the size)
# Out:
# unsigned char g_hindi_alphabets_model_data[] = {
#   0x1c, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x14, 0x00, 0x20, 0x00,
#   0x1c, 0x00, 0x18, 0x00, 0x14, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x14, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x1c, 0x00, 0x00, 0x00, 0x4c, 0x00, 0x00, 0x00, 0x08, 0x60, 0x00, 0x00,
#   0x18, 0x60, 0x00, 0x00, 0x04, 0x76, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x11, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x13, 0x00, 0x00, 0x00,
#   0x6d, 0x69, 0x6e, 0x5f, 0x72, 0x75, 0x6e, 0x74, 0x69, 0x6d, 0x65, 0x5f,
#   0x76, 0x65, 0x72, 0x73, 0x69, 0x6f, 0x6e, 0x00, 0x12, 0x00, 0x00, 0x00,
#   0xb8, 0x5f, 0x00, 0x00, 0xb0, 0x5f, 0x00, 0x00, 0x98, 0x5f, 0x00, 0x00,
#   0xd8, 0x5d, 0x00, 0x00, 0x88, 0x5d, 0x00, 0x00, 0x78, 0x4b, 0x00, 0x00,
#   0xe8, 0x4a, 0x00, 0x00, 0xd8, 0x02, 0x00, 0x00, 0xc8, 0x01, 0x00, 0x00,
#   0x78, 0x00, 0x00, 0x00, 0x54, 0x00, 0x00, 0x00, 0x4c, 0x00, 0x00, 0x00,
#   0x44, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
#   0x2c, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x06, 0xa0, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x31, 0x2e, 0x31, 0x34, 0x2e, 0x30, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x98, 0x8b, 0xff, 0xff, 0x9c, 0x8b, 0xff, 0xff,
#   0xa0, 0x8b, 0xff, 0xff, 0xa4, 0x8b, 0xff, 0xff, 0xa8, 0x8b, 0xff, 0xff,
#   0xac, 0x8b, 0xff, 0xff, 0x3a, 0xa0, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x0a, 0xf7, 0xff, 0xff, 0xf2, 0xfa, 0xff, 0xff,
#   0xa2, 0xd5, 0xff, 0xff, 0x6a, 0xda, 0xff, 0xff, 0xaf, 0x0a, 0x00, 0x00,
#   0x5a, 0xa0, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x40, 0x01, 0x00, 0x00,
#   0xfe, 0xdb, 0x18, 0x04, 0x15, 0x12, 0xc5, 0xad, 0xea, 0xad, 0x1a, 0x17,
#   0xcf, 0x21, 0xbb, 0xc5, 0x2b, 0xb5, 0x08, 0x0d, 0xb9, 0xc6, 0xcc, 0xc1,
#   0xfc, 0xc1, 0x17, 0x13, 0x9a, 0x10, 0xc0, 0xa9, 0x16, 0xe0, 0x10, 0xe7,
#   0x17, 0xab, 0xd4, 0x23, 0xc8, 0x26, 0x05, 0xbe, 0xb2, 0x1f, 0xab, 0x0b,
#   0xfc, 0xc7, 0xb9, 0x34, 0xce, 0xc3, 0xf4, 0xd5, 0xfb, 0xb1, 0xc3, 0xe4,
#   0x1c, 0x19, 0x13, 0xd2, 0x08, 0x1b, 0xb2, 0xd8, 0xa2, 0x0f, 0xd4, 0xbe,
#   0x18, 0xfa, 0xe5, 0xaf, 0x20, 0xd5, 0xc6, 0x0e, 0xe5, 0x14, 0x10, 0x06,
#   0xb8, 0xde, 0xb7, 0x0f, 0x98, 0xfd, 0xc0, 0xaf, 0x0e, 0x0c, 0xc6, 0x23,
#   0xbf, 0xdb, 0xc9, 0x4a, 0xd9, 0xfd, 0x33, 0xd7, 0xde, 0x1c, 0x20, 0x15,
#   0x0e, 0x26, 0xe4, 0xc7, 0x97, 0xb7, 0x1f, 0xe1, 0xba, 0x09, 0x45, 0xec,
#   0xbb, 0x0e, 0xf2, 0x51, 0xcb, 0xb5, 0x94, 0xaf, 0x0f, 0x1c, 0xb1, 0x10,
#   0xb7, 0xd7, 0x2b, 0x26, 0x22, 0x12, 0xc6, 0x10, 0xa2, 0xdb, 0xbd, 0x17,
#   0xca, 0xa1, 0x17, 0xca, 0x2e, 0x16, 0xca, 0x9e, 0x1c, 0xb4, 0x0d, 0x08,
#   0x92, 0xc0, 0xc0, 0xb0, 0xfc, 0x50, 0x18, 0xd2, 0x11, 0x0e, 0xd6, 0xda,
#   0x4f, 0xd0, 0xd7, 0xca, 0xb2, 0xc7, 0x12, 0x04, 0x1b, 0xd7, 0xb4, 0xda,
#   0xd8, 0x19, 0xf4, 0x41, 0xf5, 0xa4, 0x30, 0xd8, 0xee, 0xe8, 0x08, 0x10,
#   0xfa, 0xee, 0xc5, 0x81, 0xdc, 0xc3, 0x11, 0xd3, 0xcf, 0x18, 0xbb, 0xad,
#   0x0b, 0x21, 0xe2, 0x01, 0xce, 0x1b, 0xc1, 0xc6, 0xcd, 0x1c, 0x19, 0x1f,
#   0x94, 0x2c, 0xd7, 0x0a, 0x09, 0x0f, 0x21, 0xc8, 0x1a, 0xca, 0xc5, 0xb8,
#   0xc8, 0x1c, 0xaa, 0x23, 0xdf, 0xbe, 0xae, 0x13, 0x1e, 0xc4, 0x23, 0x16,
#   0xa2, 0x1e, 0xa7, 0xa6, 0x2d, 0x07, 0xa6, 0xdd, 0x38, 0xf7, 0x9f, 0xb0,
#   0x17, 0x2c, 0xea, 0x0b, 0x86, 0x93, 0x1d, 0x19, 0x23, 0xfd, 0xbf, 0x3e,
#   0x99, 0xb8, 0x11, 0xde, 0x94, 0xb9, 0x4f, 0x95, 0x03, 0xa3, 0x94, 0x0e,
#   0x3a, 0xc4, 0x31, 0xa0, 0x21, 0xc6, 0x95, 0xab, 0x23, 0x8d, 0x2c, 0x2e,
#   0xb9, 0xab, 0x8f, 0xe9, 0x8f, 0xb0, 0x13, 0xae, 0xbd, 0xac, 0x02, 0x9d,
#   0xa8, 0xa8, 0xea, 0xb2, 0x22, 0x2d, 0x33, 0xed, 0x21, 0xa4, 0xba, 0xa1,
#   0xd2, 0x2d, 0x34, 0xd2, 0xb3, 0xce, 0x03, 0x24, 0xa6, 0xa1, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0xf6, 0xf5, 0xff, 0xff,
#   0x17, 0xfa, 0xff, 0xff, 0x71, 0xf7, 0xff, 0xff, 0xfa, 0xf5, 0xff, 0xff,
#   0x93, 0xf6, 0xff, 0xff, 0x19, 0xfa, 0xff, 0xff, 0xfb, 0xf7, 0xff, 0xff,
#   0x6e, 0xf6, 0xff, 0xff, 0xbc, 0xf9, 0xff, 0xff, 0x2f, 0xf8, 0xff, 0xff,
#   0x8b, 0xf7, 0xff, 0xff, 0x91, 0xf7, 0xff, 0xff, 0x27, 0xff, 0xff, 0xff,
#   0xe6, 0xf7, 0xff, 0xff, 0x6f, 0xfa, 0xff, 0xff, 0x66, 0xf7, 0xff, 0xff,
#   0x4d, 0xf9, 0xff, 0xff, 0x6c, 0xfd, 0xff, 0xff, 0xbe, 0xf8, 0xff, 0xff,
#   0xb8, 0xfa, 0xff, 0xff, 0x84, 0xf7, 0xff, 0xff, 0xee, 0xf6, 0xff, 0xff,
#   0xaf, 0xfa, 0xff, 0xff, 0xe4, 0xfd, 0xff, 0xff, 0x46, 0xf7, 0xff, 0xff,
#   0x74, 0xfc, 0xff, 0xff, 0x0d, 0xf3, 0xff, 0xff, 0xcc, 0xf6, 0xff, 0xff,
#   0x36, 0xfd, 0xff, 0xff, 0x34, 0xf8, 0xff, 0xff, 0xf3, 0xfa, 0xff, 0xff,
#   0x00, 0xfe, 0xff, 0xff, 0x64, 0xf3, 0xff, 0xff, 0xfe, 0xf1, 0xff, 0xff,
#   0x74, 0xf1, 0xff, 0xff, 0x7a, 0xff, 0xff, 0xff, 0x2e, 0xf5, 0xff, 0xff,
#   0xcd, 0xf6, 0xff, 0xff, 0xd1, 0xfc, 0xff, 0xff, 0x2a, 0xf6, 0xff, 0xff,
#   0x1e, 0xf2, 0xff, 0xff, 0xac, 0xf9, 0xff, 0xff, 0x15, 0xfc, 0xff, 0xff,
#   0x10, 0xfd, 0xff, 0xff, 0xed, 0xfc, 0xff, 0xff, 0x31, 0xfd, 0xff, 0xff,
#   0xa3, 0xf9, 0xff, 0xff, 0xd7, 0xf2, 0xff, 0xff, 0xa8, 0xf4, 0xff, 0xff,
#   0x50, 0xfb, 0xff, 0xff, 0x23, 0xfd, 0xff, 0xff, 0x44, 0xf8, 0xff, 0xff,
#   0xb1, 0xfb, 0xff, 0xff, 0x5a, 0xf5, 0xff, 0xff, 0x85, 0xfe, 0xff, 0xff,
#   0xcc, 0xf3, 0xff, 0xff, 0xa0, 0xf9, 0xff, 0xff, 0xc1, 0xfb, 0xff, 0xff,
#   0x07, 0xf9, 0xff, 0xff, 0x04, 0xff, 0xff, 0xff, 0x2d, 0xf4, 0xff, 0xff,
#   0xb5, 0xf7, 0xff, 0xff, 0x23, 0xf7, 0xff, 0xff, 0xee, 0xf5, 0xff, 0xff,
#   0xb2, 0xa2, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x00, 0x48, 0x00, 0x00,
#   0x09, 0xf5, 0x01, 0x20, 0xd9, 0xd3, 0xcd, 0x1a, 0xd3, 0xf7, 0xe7, 0xe8,
#   0xf2, 0xf6, 0x01, 0xee, 0xea, 0xc8, 0x12, 0xfd, 0x2b, 0xe8, 0xf2, 0xcd,
#   0x34, 0xf8, 0xe8, 0x3f, 0xd7, 0xf8, 0x30, 0xce, 0x03, 0x25, 0x14, 0x21,
#   0x12, 0x09, 0xdf, 0x1e, 0x16, 0x13, 0xfb, 0x04, 0x1a, 0x1b, 0x3f, 0xf7,
#   0xfb, 0x16, 0x31, 0x2e, 0xfc, 0xc2, 0xe5, 0xc8, 0x51, 0x1d, 0xe6, 0x42,
#   0x2b, 0x03, 0x26, 0xfc, 0x1f, 0x05, 0x12, 0xfb, 0xed, 0x1f, 0xe5, 0x2d,
#   0x23, 0x20, 0xfc, 0xee, 0x1c, 0x28, 0x11, 0xf8, 0x01, 0xfd, 0x0a, 0x0d,
#   0x09, 0x05, 0x08, 0x05, 0x59, 0xf1, 0x14, 0x6c, 0x2a, 0xfe, 0x16, 0x09,
#   0x35, 0x28, 0xf9, 0xf9, 0x09, 0xed, 0xab, 0x32, 0x08, 0x05, 0xf3, 0xca,
#   0x02, 0x34, 0xf9, 0xfa, 0x98, 0xbd, 0x1a, 0xf3, 0xed, 0xca, 0xaf, 0xd8,
#   0x27, 0xf0, 0x01, 0x49, 0x28, 0xd3, 0x3d, 0x15, 0x6d, 0x4a, 0xf7, 0xd6,
#   0x22, 0x2e, 0xcb, 0x41, 0x30, 0xf0, 0x18, 0xe2, 0xd7, 0x4c, 0x37, 0x12,
#   0xa6, 0x12, 0x09, 0x19, 0xa9, 0x02, 0xba, 0xbf, 0x72, 0xda, 0x0b, 0x54,
#   0x4c, 0xe1, 0x39, 0x29, 0x53, 0x18, 0xf6, 0x0a, 0x1b, 0x18, 0xd8, 0x1d,
#   0x23, 0x0f, 0xf8, 0xf0, 0xe3, 0x4e, 0x0c, 0xff, 0xe9, 0xf5, 0x0c, 0xfd,
#   0x05, 0xf3, 0xe6, 0xf4, 0x7f, 0x00, 0x20, 0x62, 0x27, 0x02, 0x20, 0x17,
#   0x0c, 0x12, 0x0b, 0xdb, 0xff, 0x2b, 0xce, 0x2a, 0x20, 0x1c, 0xfe, 0xbe,
#   0xef, 0x22, 0x06, 0x13, 0x86, 0x17, 0x0d, 0x12, 0xf3, 0xed, 0xc5, 0xe1,
#   0x14, 0x0a, 0x0f, 0x42, 0x29, 0xe1, 0x3d, 0xef, 0x13, 0x34, 0xfb, 0xe5,
#   0xe3, 0x30, 0xf6, 0x10, 0x1a, 0xf7, 0x0a, 0xd9, 0xf4, 0x2a, 0x29, 0x09,
#   0xcc, 0xe3, 0x12, 0x10, 0xc5, 0x00, 0xcd, 0xe6, 0x62, 0x05, 0x10, 0x25,
#   0x0c, 0x00, 0x1a, 0x0a, 0xfd, 0x0a, 0xf2, 0xea, 0xe0, 0x0a, 0xff, 0x13,
#   0x29, 0x3d, 0xe0, 0xf0, 0xcc, 0x0d, 0x0d, 0x13, 0xff, 0x23, 0xfe, 0x10,
#   0xd5, 0x14, 0x08, 0xf6, 0x59, 0xf3, 0x18, 0x56, 0x28, 0xfc, 0x1b, 0xf0,
#   0xff, 0x25, 0x2b, 0xe1, 0x0f, 0xb1, 0xe5, 0xe8, 0x49, 0xfe, 0xdb, 0x09,
#   0xf0, 0x39, 0x0c, 0xa9, 0xbc, 0xc5, 0x10, 0x08, 0xee, 0xea, 0xde, 0x0d,
#   0x12, 0xfd, 0xfb, 0x2f, 0xe2, 0xab, 0x49, 0x8f, 0x2d, 0x2b, 0x18, 0xd8,
#   0x04, 0xcb, 0xd0, 0x10, 0x32, 0xf5, 0x0c, 0xe8, 0xe1, 0x27, 0x34, 0xfb,
#   0xd0, 0xc6, 0x08, 0x2d, 0xbb, 0xf3, 0xcc, 0xeb, 0x32, 0x06, 0x2b, 0x11,
#   0xd4, 0xc7, 0x57, 0xe2, 0x42, 0x0e, 0xf7, 0xe6, 0xe8, 0xe2, 0x00, 0x07,
#   0x28, 0x35, 0x0b, 0xee, 0xd0, 0x2b, 0x1d, 0x28, 0xe1, 0xd6, 0xbf, 0xf6,
#   0xdf, 0xff, 0xf5, 0x22, 0x4a, 0xd3, 0x40, 0xe0, 0x03, 0xdb, 0x3a, 0x0e,
#   0x57, 0x2b, 0xeb, 0xbf, 0xf0, 0x14, 0xb1, 0x0f, 0xfc, 0x0d, 0xf6, 0xf4,
#   0xb8, 0x23, 0x11, 0xfb, 0x9d, 0xb0, 0xee, 0xca, 0xcd, 0xff, 0xcb, 0xb5,
#   0x26, 0xe3, 0x39, 0x36, 0xea, 0xd0, 0xf2, 0xfa, 0x5b, 0x4a, 0xf8, 0xb7,
#   0xfc, 0x06, 0x90, 0x1c, 0x35, 0x2c, 0x1f, 0xeb, 0x9f, 0x3e, 0x3f, 0x12,
#   0xd7, 0xc6, 0x16, 0x1a, 0x81, 0x05, 0xad, 0xa4, 0x67, 0xdc, 0x2d, 0x42,
#   0xf4, 0xde, 0x6d, 0x1b, 0x48, 0x33, 0x34, 0xc8, 0x0c, 0xd5, 0xbd, 0xfb,
#   0x32, 0x31, 0xf7, 0xea, 0xc7, 0x3e, 0x0c, 0x04, 0xf1, 0xbb, 0xe5, 0x1b,
#   0xcf, 0x14, 0xeb, 0xff, 0x62, 0xf3, 0x48, 0x24, 0xea, 0xb0, 0x3f, 0x05,
#   0x28, 0xe4, 0x10, 0x12, 0xe8, 0xd3, 0xcb, 0x2f, 0x21, 0xfe, 0x1c, 0xd9,
#   0x07, 0x46, 0xf6, 0x2a, 0xaf, 0xe1, 0xde, 0x20, 0xf3, 0xd3, 0xd2, 0x04,
#   0x23, 0x1f, 0x0c, 0x30, 0xf5, 0xc1, 0x25, 0x13, 0x29, 0x2e, 0xf0, 0xf2,
#   0x25, 0xe4, 0x85, 0x1a, 0x3f, 0x08, 0x22, 0xd6, 0xe7, 0x26, 0x27, 0x05,
#   0xd6, 0xc9, 0x03, 0x1e, 0xec, 0xf4, 0xbc, 0xc4, 0x63, 0x06, 0x4a, 0x1d,
#   0xe4, 0xba, 0x3a, 0xe2, 0x3e, 0x22, 0x0a, 0xe4, 0x05, 0xfe, 0xec, 0xfd,
#   0x16, 0x26, 0xfd, 0xf9, 0xd3, 0x25, 0x1f, 0xed, 0xe3, 0xf4, 0x1b, 0x1d,
#   0xd6, 0xeb, 0x0a, 0xf3, 0x3e, 0xf5, 0x2c, 0x2c, 0xd6, 0xd8, 0x13, 0xc8,
#   0xbf, 0xeb, 0xd8, 0x15, 0xfc, 0xc1, 0xfd, 0x03, 0xb7, 0x9f, 0x02, 0x27,
#   0x34, 0xb2, 0xfe, 0xec, 0x4f, 0x21, 0xe8, 0xf5, 0x0a, 0x3a, 0x36, 0xf2,
#   0xd4, 0x1c, 0x0b, 0x09, 0x35, 0xea, 0xd2, 0x16, 0xe2, 0x19, 0xd4, 0x33,
#   0xec, 0x02, 0x19, 0x11, 0xa4, 0xa1, 0xe7, 0x33, 0x22, 0x9e, 0xd7, 0x01,
#   0x31, 0x0e, 0x0b, 0xcf, 0x02, 0x38, 0x47, 0xe7, 0xe8, 0xe3, 0xbb, 0x1d,
#   0x47, 0x1d, 0xc9, 0x32, 0xe8, 0x08, 0xf3, 0x14, 0xd8, 0xeb, 0xdc, 0xf7,
#   0xca, 0xbb, 0xed, 0x16, 0x1d, 0xc6, 0xf9, 0xef, 0x34, 0xd2, 0x09, 0xf0,
#   0x2c, 0x28, 0x12, 0xfa, 0x0e, 0xf4, 0x22, 0xe0, 0x12, 0xee, 0xca, 0x0d,
#   0xce, 0x0d, 0xd2, 0x28, 0xdf, 0xfb, 0xfe, 0xfa, 0xba, 0x96, 0x0b, 0x3f,
#   0x1d, 0x9f, 0xfb, 0x01, 0x58, 0x19, 0x2a, 0xd5, 0x1f, 0x22, 0x37, 0xe6,
#   0xc2, 0x27, 0xf2, 0xf1, 0x11, 0x47, 0xdf, 0xfd, 0xbe, 0xf6, 0x84, 0x21,
#   0xc4, 0x13, 0x22, 0xfc, 0x81, 0xb1, 0xf4, 0x42, 0x10, 0x8c, 0xd0, 0xf1,
#   0x4f, 0x07, 0x0f, 0xb1, 0x0c, 0x4e, 0x63, 0xe0, 0xed, 0xe8, 0x0e, 0x11,
#   0x51, 0x36, 0x98, 0x04, 0xd2, 0x1b, 0xc1, 0x08, 0xd1, 0x0b, 0x04, 0xfe,
#   0xa8, 0xb5, 0xda, 0x2b, 0x15, 0x9e, 0x15, 0xe0, 0x55, 0xe5, 0x06, 0xeb,
#   0x19, 0x33, 0x2f, 0xec, 0xeb, 0xc6, 0xfc, 0xdc, 0x26, 0x16, 0xa0, 0x06,
#   0xbf, 0xf7, 0xd6, 0xf0, 0xda, 0x10, 0x12, 0xec, 0xe1, 0xe3, 0xdf, 0xf2,
#   0x02, 0xcc, 0xe2, 0xe3, 0x22, 0x62, 0x0e, 0xd3, 0xfc, 0x31, 0x1f, 0xf6,
#   0xc3, 0xfb, 0xd9, 0xf1, 0x42, 0x1f, 0xc8, 0xdb, 0xb8, 0x10, 0xac, 0xbd,
#   0xcb, 0x30, 0x32, 0xed, 0xa1, 0xe0, 0xc4, 0x29, 0xc8, 0xaa, 0xfb, 0xf8,
#   0x3b, 0x2a, 0x39, 0xb0, 0xd4, 0x5e, 0x28, 0xfa, 0xe8, 0x98, 0xcd, 0x1f,
#   0x57, 0x38, 0xc0, 0x04, 0xd8, 0x0b, 0xaf, 0x9f, 0x94, 0x0a, 0xed, 0xd2,
#   0xc0, 0xdd, 0xa5, 0x0d, 0xc4, 0xc9, 0x0f, 0xd5, 0xfd, 0x25, 0x30, 0xe9,
#   0xc9, 0x2b, 0xf3, 0xf4, 0xc9, 0xbd, 0x0b, 0xe7, 0x39, 0x1b, 0xb8, 0xf7,
#   0x40, 0x35, 0xfe, 0x0f, 0x0a, 0x28, 0xfb, 0xe7, 0x05, 0xf6, 0xf3, 0x10,
#   0xf6, 0x34, 0x16, 0xf8, 0x22, 0x10, 0x49, 0xfa, 0x09, 0x45, 0x0e, 0x03,
#   0x2d, 0x08, 0x38, 0x09, 0x10, 0x36, 0x05, 0xf0, 0x2e, 0x33, 0xeb, 0x25,
#   0xe4, 0x34, 0xfc, 0xfa, 0x05, 0x00, 0xd9, 0x14, 0xef, 0x02, 0x3d, 0xe3,
#   0x20, 0x07, 0x22, 0xff, 0xe5, 0x32, 0x2a, 0xd4, 0x0d, 0xde, 0x22, 0x04,
#   0x02, 0x0f, 0xf6, 0xd5, 0x03, 0x73, 0x06, 0xe6, 0xf2, 0x0e, 0xd2, 0xdb,
#   0x06, 0xfe, 0xb4, 0xe0, 0xd8, 0xee, 0x20, 0xb5, 0xfe, 0xcd, 0x0e, 0xdc,
#   0xdf, 0x59, 0xe3, 0x06, 0x08, 0xc7, 0x2b, 0xc7, 0xf8, 0xe4, 0xf2, 0xd7,
#   0x2f, 0x44, 0xce, 0x0a, 0x03, 0x5e, 0x1c, 0xf6, 0x05, 0x0b, 0xe8, 0x4c,
#   0xf9, 0x15, 0x45, 0xdd, 0x48, 0xf7, 0x3e, 0x0f, 0xf6, 0x39, 0x11, 0xea,
#   0x0c, 0xe3, 0x07, 0x03, 0x03, 0x45, 0xe4, 0xd9, 0x0f, 0x50, 0xd9, 0xd2,
#   0xe9, 0x57, 0xf7, 0xe0, 0xeb, 0x1f, 0xb6, 0x51, 0xb7, 0x07, 0x3e, 0xdc,
#   0x18, 0xfe, 0x47, 0xef, 0xf5, 0x2d, 0x52, 0xae, 0x0f, 0xb5, 0x3b, 0x07,
#   0xfe, 0x2e, 0xda, 0xad, 0x31, 0x3d, 0xd9, 0xb5, 0xdb, 0x16, 0xf6, 0xd4,
#   0xea, 0xf3, 0x81, 0x12, 0xb9, 0x04, 0x30, 0xc1, 0xf8, 0x0e, 0x25, 0xdc,
#   0xa8, 0x5f, 0xe3, 0xf7, 0x2b, 0x94, 0x06, 0xd3, 0xee, 0x04, 0xb8, 0xb2,
#   0x19, 0x28, 0xba, 0xf5, 0xfc, 0x57, 0x01, 0xde, 0x05, 0xfe, 0xe4, 0x32,
#   0xe0, 0xff, 0x47, 0xbb, 0x01, 0xef, 0x30, 0xe4, 0xf4, 0x1c, 0x05, 0xe2,
#   0xe6, 0x03, 0x1c, 0xf7, 0xec, 0x28, 0xb9, 0xde, 0x0c, 0x24, 0xae, 0xe1,
#   0xb9, 0x37, 0xf3, 0xc5, 0xf9, 0xfd, 0xb1, 0x1e, 0xd5, 0xf0, 0x3e, 0xb0,
#   0x13, 0x00, 0x1c, 0xc4, 0xee, 0x2f, 0x15, 0xd3, 0xed, 0xc5, 0x20, 0x17,
#   0xfa, 0x10, 0xc6, 0xb2, 0x17, 0x27, 0xca, 0xda, 0xaf, 0x22, 0xfa, 0xd2,
#   0xef, 0x0d, 0xaa, 0x03, 0xc5, 0xf5, 0x4c, 0xbf, 0x03, 0xfd, 0xee, 0xb9,
#   0xcb, 0x2f, 0xf1, 0xee, 0xff, 0xb5, 0xda, 0xd0, 0x14, 0xfa, 0xef, 0xf0,
#   0xa9, 0x26, 0xe5, 0x17, 0x07, 0xef, 0xf8, 0xf2, 0xb8, 0xc0, 0x00, 0x1f,
#   0x07, 0xc2, 0x02, 0xfc, 0x61, 0x08, 0xc8, 0xf4, 0xf6, 0x1f, 0x53, 0x0c,
#   0xe1, 0x0e, 0xfc, 0x01, 0x45, 0x0a, 0xd8, 0x0b, 0xda, 0xba, 0xbd, 0x27,
#   0xf4, 0xe8, 0x56, 0x01, 0xad, 0xba, 0xf5, 0x47, 0x2e, 0xbd, 0xc4, 0x09,
#   0x37, 0x15, 0xf4, 0xd0, 0x1b, 0x2d, 0x5d, 0xf7, 0xb9, 0xf4, 0xdd, 0x0f,
#   0x65, 0x3a, 0xdf, 0x2c, 0xeb, 0x2a, 0xe0, 0xfd, 0x03, 0xe3, 0x09, 0x09,
#   0xc1, 0xc3, 0xdc, 0x16, 0x1f, 0xd2, 0x09, 0xfb, 0x54, 0xe3, 0x12, 0xf4,
#   0x2d, 0x38, 0x2f, 0xf9, 0xf7, 0x0c, 0x2e, 0xe1, 0x1b, 0x0a, 0xce, 0x0e,
#   0xa4, 0x08, 0xc9, 0x24, 0xe7, 0x0c, 0x0b, 0x0d, 0xc2, 0xb3, 0x15, 0x33,
#   0x20, 0x95, 0x04, 0xee, 0x54, 0x28, 0x21, 0xc3, 0xfa, 0x1e, 0x4d, 0xe8,
#   0xb9, 0x05, 0xce, 0x01, 0x26, 0x3c, 0xcd, 0x0b, 0x85, 0xff, 0x92, 0x1d,
#   0xc3, 0x06, 0x3c, 0x02, 0x85, 0xdd, 0xf6, 0x5b, 0x39, 0x81, 0xc4, 0xe9,
#   0x5f, 0x0c, 0xfd, 0xb1, 0x2a, 0x45, 0x7a, 0xf4, 0xd6, 0xe6, 0x03, 0x0d,
#   0x31, 0x3b, 0xb9, 0x0a, 0xc2, 0x0e, 0xba, 0x28, 0xc2, 0x0a, 0x09, 0x12,
#   0xac, 0xc1, 0xf4, 0x1a, 0x11, 0x9e, 0x1a, 0xf7, 0x4e, 0x0d, 0xfd, 0xdc,
#   0x05, 0x3a, 0x2b, 0xeb, 0xdb, 0xed, 0xf1, 0xba, 0x16, 0x2a, 0xac, 0x12,
#   0x9d, 0x05, 0xc8, 0xf4, 0xec, 0x18, 0x0a, 0xed, 0xc8, 0xe3, 0xe3, 0xf7,
#   0xfe, 0xbb, 0xb0, 0xfe, 0x11, 0x5c, 0x08, 0xe3, 0x03, 0x0e, 0x2c, 0xfe,
#   0xcb, 0xfa, 0xf1, 0xec, 0x4a, 0x34, 0xd0, 0xe5, 0xd5, 0x0e, 0xae, 0xd7,
#   0xa5, 0x36, 0x32, 0xc8, 0x90, 0xf3, 0xb2, 0x0a, 0xc2, 0x93, 0xc9, 0xde,
#   0x21, 0x4a, 0x41, 0xa5, 0x19, 0x5c, 0x30, 0xd3, 0xea, 0xb1, 0xf3, 0x15,
#   0x31, 0x2c, 0xb3, 0x08, 0xab, 0x16, 0xa3, 0xb5, 0xc6, 0x16, 0xe8, 0xb8,
#   0xd1, 0xb2, 0xc0, 0x02, 0xb7, 0xd2, 0xff, 0xd2, 0x07, 0x4e, 0x31, 0xc1,
#   0xd1, 0x15, 0x17, 0xdd, 0xe9, 0xd6, 0x0e, 0xd8, 0x32, 0x3a, 0xc4, 0xcd,
#   0xcf, 0x00, 0xc2, 0x1c, 0xf4, 0xff, 0xb3, 0x26, 0xce, 0xa3, 0x19, 0xf6,
#   0x0f, 0xdf, 0xb4, 0x2a, 0xf7, 0x14, 0x0c, 0xff, 0xfd, 0x38, 0x00, 0xce,
#   0xf0, 0x1e, 0x2d, 0x1a, 0x35, 0x2d, 0xde, 0x4c, 0xd7, 0x20, 0xa8, 0x10,
#   0xe2, 0xe5, 0xdc, 0x3f, 0x8a, 0x97, 0x00, 0x32, 0x17, 0xc9, 0xba, 0x1a,
#   0x0b, 0x1a, 0x00, 0xb0, 0x16, 0x48, 0x34, 0xca, 0xee, 0xef, 0x23, 0x2b,
#   0x38, 0x1b, 0xc2, 0x48, 0xec, 0x30, 0xce, 0x23, 0xc1, 0x04, 0xeb, 0x00,
#   0xcc, 0xd7, 0xe2, 0xff, 0x0c, 0xe3, 0xeb, 0xfd, 0x01, 0x27, 0x15, 0xd3,
#   0x0e, 0x27, 0xfc, 0xef, 0xeb, 0xd9, 0xfc, 0x08, 0x22, 0xfd, 0xca, 0xf4,
#   0xec, 0x43, 0xcb, 0x04, 0xaf, 0x02, 0xab, 0x1e, 0xc8, 0xb3, 0xf0, 0x25,
#   0xeb, 0xc7, 0xf3, 0x19, 0x33, 0x03, 0xff, 0xd1, 0x0f, 0x48, 0x17, 0xe2,
#   0x0b, 0x06, 0x50, 0x2d, 0x37, 0xf9, 0xe6, 0x2c, 0xbf, 0x35, 0xa2, 0x19,
#   0xc0, 0xf6, 0xdb, 0x4a, 0xbb, 0x8d, 0x04, 0x32, 0x08, 0x9b, 0xdc, 0x0a,
#   0x2e, 0x0a, 0xf5, 0x81, 0x08, 0x4b, 0x35, 0xa0, 0xfe, 0xf2, 0x43, 0x25,
#   0x65, 0x02, 0xcc, 0x3f, 0xef, 0x58, 0xa9, 0x10, 0xae, 0x18, 0xde, 0x31,
#   0xbb, 0xc5, 0x01, 0x03, 0xeb, 0xd5, 0xf8, 0xdc, 0x1f, 0x05, 0x0a, 0xa4,
#   0x03, 0x59, 0xf8, 0xc2, 0xee, 0xd3, 0x50, 0x17, 0x11, 0xfc, 0xab, 0x37,
#   0xf8, 0x29, 0xf7, 0xfa, 0xf3, 0xfd, 0xcb, 0xfd, 0xec, 0xda, 0xfa, 0x09,
#   0x0b, 0x07, 0x04, 0x0f, 0x15, 0x15, 0x24, 0x0a, 0xfb, 0x4d, 0x02, 0x0c,
#   0x35, 0x08, 0x3e, 0x2d, 0x22, 0x0e, 0xfd, 0x1e, 0xea, 0x4c, 0xd7, 0xe1,
#   0xc4, 0xe4, 0x11, 0x4d, 0xe3, 0xcb, 0x18, 0x0e, 0xd3, 0xd9, 0x0e, 0x22,
#   0x09, 0x06, 0x0a, 0xe7, 0xf0, 0x33, 0x1b, 0xc2, 0x0a, 0xee, 0x27, 0x67,
#   0x54, 0x07, 0xf0, 0x3f, 0xec, 0x2e, 0xa4, 0xd8, 0x96, 0xf8, 0xe3, 0x04,
#   0xef, 0xd7, 0xd8, 0xf4, 0xcd, 0xe9, 0x13, 0x03, 0x16, 0x1a, 0x29, 0xd2,
#   0xcb, 0x42, 0xf3, 0x9e, 0xf5, 0xc0, 0x38, 0x14, 0x0d, 0xfe, 0xdb, 0x24,
#   0x32, 0x04, 0x15, 0x18, 0xee, 0x1a, 0xfd, 0xc7, 0x30, 0x29, 0xc6, 0xfc,
#   0x0b, 0x16, 0x1a, 0xb4, 0xfe, 0xe4, 0x02, 0xf9, 0x06, 0xed, 0xf5, 0x00,
#   0x24, 0xc2, 0xdc, 0xe5, 0xdb, 0xfa, 0xd8, 0x98, 0x19, 0xf1, 0x14, 0x09,
#   0x11, 0xf9, 0x01, 0xcc, 0x2c, 0x18, 0xc2, 0xe9, 0x0c, 0x4c, 0x1e, 0xc3,
#   0xf7, 0xee, 0x18, 0x0f, 0xfb, 0xf8, 0xe0, 0x0c, 0x38, 0xd9, 0xe8, 0xbc,
#   0xe9, 0xe7, 0x0d, 0xb3, 0x2a, 0xe6, 0x0d, 0x08, 0x09, 0xd3, 0x10, 0xd8,
#   0x2c, 0xda, 0x02, 0x1a, 0x0a, 0x24, 0x0f, 0xbf, 0xfc, 0xd5, 0xfd, 0xfb,
#   0x04, 0xb6, 0xe6, 0x11, 0x08, 0xed, 0xcb, 0xf4, 0xf8, 0xfe, 0x12, 0xad,
#   0x2b, 0xf9, 0x1f, 0x20, 0x5b, 0x44, 0x2e, 0xca, 0x2e, 0x43, 0xd1, 0xd9,
#   0x0e, 0x49, 0x09, 0xd1, 0xc2, 0xf6, 0x33, 0x1c, 0x0e, 0xbe, 0xd7, 0x0f,
#   0x27, 0xd3, 0xee, 0x07, 0xde, 0x11, 0x24, 0xcd, 0x3a, 0xe4, 0x3a, 0x08,
#   0x0c, 0x3c, 0x26, 0xab, 0x43, 0x7f, 0xd4, 0xd8, 0x08, 0x4f, 0x58, 0xd9,
#   0xbe, 0x1b, 0x1a, 0x35, 0xf3, 0xdc, 0xc4, 0x0f, 0x15, 0xcb, 0xd3, 0xe3,
#   0xe2, 0x04, 0x28, 0xcd, 0x30, 0xd4, 0x28, 0x15, 0x1e, 0x57, 0x09, 0xeb,
#   0x1a, 0x46, 0x00, 0x05, 0x13, 0x21, 0x2f, 0xcf, 0xde, 0xc2, 0x13, 0x29,
#   0xef, 0xbb, 0xd8, 0x16, 0xf3, 0xc1, 0xd2, 0xe3, 0xe9, 0x06, 0x0f, 0xb2,
#   0x20, 0xfa, 0x24, 0xdb, 0x2c, 0x15, 0x09, 0xf3, 0x2b, 0x0a, 0x20, 0xff,
#   0xe6, 0x27, 0x09, 0xe6, 0xd6, 0xe2, 0xfe, 0x11, 0xe9, 0xea, 0x00, 0xf4,
#   0x11, 0x02, 0x01, 0x00, 0xfb, 0x09, 0x25, 0xe2, 0x2b, 0xfb, 0x25, 0x06,
#   0xe5, 0x28, 0x09, 0xcb, 0x4b, 0x2a, 0xd4, 0xc4, 0x0f, 0x3e, 0x21, 0xeb,
#   0xb7, 0xe6, 0x1f, 0x29, 0xec, 0xd8, 0xcf, 0x1c, 0xf8, 0xf5, 0xfd, 0xf0,
#   0xe5, 0x06, 0x12, 0xcc, 0x12, 0xf4, 0x28, 0x0c, 0x0e, 0x1a, 0x21, 0xf0,
#   0x04, 0x26, 0x0d, 0x12, 0x07, 0x09, 0x18, 0xf1, 0xdc, 0xfe, 0x2b, 0x1e,
#   0x06, 0xd0, 0xe6, 0x30, 0x00, 0xfd, 0x01, 0xed, 0x07, 0x15, 0x21, 0xf9,
#   0x21, 0xe9, 0x03, 0x1d, 0x13, 0xe0, 0x08, 0xc4, 0x1f, 0xf2, 0xd9, 0x51,
#   0xe6, 0x4c, 0x28, 0xb4, 0x28, 0xe1, 0x09, 0x00, 0xd7, 0x00, 0x0f, 0xf1,
#   0x43, 0xd5, 0xeb, 0xf7, 0xc7, 0xea, 0xfb, 0x9d, 0x3c, 0xe7, 0xf7, 0xf8,
#   0x17, 0xbb, 0x2b, 0xb2, 0x42, 0x0e, 0xc0, 0x36, 0xd3, 0x2c, 0x32, 0xa9,
#   0x40, 0xb9, 0xf5, 0xf0, 0xca, 0x19, 0x4a, 0x15, 0x1c, 0xcb, 0x19, 0xb0,
#   0xa0, 0xf6, 0x14, 0xb0, 0x14, 0x15, 0x01, 0x10, 0xea, 0xe1, 0x05, 0xe9,
#   0x12, 0xce, 0xfe, 0x23, 0x08, 0xe4, 0x0f, 0xce, 0x55, 0xb9, 0x1c, 0x10,
#   0x04, 0x37, 0x07, 0x07, 0x0c, 0xfa, 0x23, 0xe9, 0xe1, 0x05, 0x0a, 0xaf,
#   0x4c, 0xff, 0xdf, 0xe7, 0x1b, 0x19, 0x1e, 0xae, 0x10, 0x67, 0xe0, 0x43,
#   0xd6, 0x28, 0x27, 0xa7, 0x45, 0xcf, 0x1b, 0x48, 0xc4, 0xf4, 0x30, 0xe2,
#   0x3d, 0xe3, 0xfd, 0x05, 0xb5, 0x07, 0xea, 0x8f, 0x3a, 0x29, 0x07, 0xb0,
#   0x20, 0x2d, 0x26, 0xab, 0x31, 0x6d, 0xd2, 0x53, 0xa2, 0x2e, 0x45, 0x9d,
#   0x57, 0xa9, 0x08, 0x5c, 0x83, 0x36, 0x52, 0xea, 0x2f, 0xc0, 0x26, 0xd8,
#   0xcc, 0xf2, 0x2a, 0x84, 0x2d, 0x20, 0x47, 0x02, 0x03, 0x0f, 0x05, 0xe0,
#   0x1c, 0xfb, 0xb9, 0x3c, 0x04, 0x25, 0x41, 0xb3, 0x30, 0xa7, 0x15, 0x3e,
#   0xb3, 0x26, 0x08, 0x10, 0x1d, 0xc3, 0x13, 0xda, 0xd3, 0x0d, 0x09, 0xa7,
#   0x03, 0xf8, 0xe5, 0xf3, 0xef, 0x29, 0xfa, 0xc4, 0xf9, 0x12, 0xea, 0x33,
#   0xdd, 0xe5, 0x18, 0xb6, 0x17, 0x09, 0x1a, 0xfe, 0x0b, 0x0e, 0x3f, 0xfb,
#   0x02, 0xcf, 0xf3, 0xfe, 0xf3, 0x02, 0xe2, 0xb4, 0x05, 0x13, 0xe8, 0xcd,
#   0xdf, 0x0e, 0xed, 0x8f, 0x2e, 0x10, 0x8f, 0x31, 0xd2, 0xe1, 0x51, 0xa1,
#   0x2e, 0xe4, 0x31, 0xf3, 0xc4, 0x1f, 0x62, 0x07, 0x31, 0xad, 0x06, 0xd6,
#   0xca, 0xf1, 0xaa, 0x9f, 0x04, 0x09, 0x2a, 0xa9, 0xe8, 0x01, 0xec, 0x9e,
#   0x31, 0xfa, 0x93, 0x35, 0xbd, 0x08, 0x65, 0x81, 0x27, 0xe7, 0x36, 0x07,
#   0xa3, 0x20, 0x01, 0xd5, 0x12, 0xc9, 0x0e, 0xc3, 0xf0, 0xf5, 0x35, 0xc2,
#   0x00, 0x07, 0x0f, 0xfb, 0xf8, 0x0f, 0xc9, 0xc9, 0x19, 0x21, 0xf2, 0xf9,
#   0xf5, 0x21, 0xed, 0xc1, 0xc5, 0xb9, 0x07, 0xfa, 0xf6, 0xf5, 0xc0, 0x0a,
#   0x0b, 0xc2, 0xf5, 0x18, 0xe8, 0xbc, 0xfe, 0xa9, 0x2d, 0x41, 0xe9, 0x23,
#   0xf8, 0x06, 0xb5, 0xe8, 0x1d, 0x08, 0xdf, 0xdf, 0x08, 0x36, 0x3f, 0xb5,
#   0xdd, 0xe1, 0x24, 0x20, 0xba, 0x0a, 0xce, 0xd8, 0x26, 0xc6, 0x22, 0x33,
#   0xdd, 0xaf, 0x24, 0x8e, 0x2a, 0x38, 0x25, 0xf0, 0x0e, 0x0a, 0xed, 0xea,
#   0x41, 0x0a, 0xe1, 0x16, 0xe8, 0x1e, 0x17, 0xe9, 0xf6, 0xc8, 0x17, 0x0a,
#   0xf5, 0x05, 0x10, 0x03, 0x4e, 0xcd, 0x1c, 0x0f, 0xf1, 0xdf, 0x05, 0xc0,
#   0x69, 0x31, 0xef, 0xaa, 0xd2, 0x1c, 0xb6, 0x17, 0x22, 0xf0, 0xda, 0xc6,
#   0xa9, 0x33, 0x1e, 0x12, 0x87, 0xbd, 0x0a, 0xd5, 0xdb, 0x0a, 0xa5, 0xb3,
#   0x40, 0xd7, 0x31, 0x45, 0xf8, 0xcb, 0x03, 0x25, 0x47, 0x5a, 0xd9, 0xbb,
#   0xdf, 0x3e, 0xae, 0x21, 0x24, 0x3b, 0xe8, 0xd5, 0xa7, 0x3c, 0x61, 0xed,
#   0xb0, 0xdd, 0x30, 0x08, 0x89, 0xee, 0xb4, 0x97, 0x7f, 0xb8, 0x42, 0x48,
#   0xe8, 0xf4, 0x2d, 0xf7, 0x4e, 0x47, 0x0c, 0xac, 0xf0, 0x27, 0xd3, 0x1e,
#   0x31, 0x10, 0x08, 0xe8, 0xc9, 0x22, 0x25, 0x05, 0xf0, 0xdb, 0xfe, 0xfa,
#   0xc6, 0x08, 0xec, 0xd4, 0x56, 0xdb, 0x41, 0x39, 0xf6, 0xe2, 0x3c, 0xe7,
#   0xfe, 0xe9, 0x10, 0xf9, 0x05, 0xcc, 0xc0, 0x22, 0x1b, 0xc9, 0x1e, 0xe4,
#   0xf9, 0x2f, 0xe9, 0x21, 0xcb, 0xc3, 0xe6, 0x1c, 0xf8, 0xe5, 0xcf, 0x06,
#   0xf6, 0x13, 0x0c, 0x38, 0xe9, 0xb3, 0x22, 0x16, 0x18, 0x11, 0xf4, 0x24,
#   0x0a, 0xf9, 0x9b, 0x2b, 0x10, 0x06, 0x07, 0xed, 0xef, 0x26, 0x20, 0x13,
#   0xca, 0xc9, 0xe9, 0x1b, 0xd0, 0xee, 0xd8, 0xc4, 0x41, 0x11, 0x3d, 0x3d,
#   0x06, 0xd3, 0x60, 0xfd, 0x36, 0x3c, 0x07, 0xeb, 0xca, 0x0f, 0xe2, 0x26,
#   0x28, 0xec, 0xd5, 0x12, 0xa5, 0x03, 0x17, 0x0d, 0xee, 0xd5, 0x10, 0xfd,
#   0xe2, 0x0a, 0x09, 0xe9, 0x36, 0xdd, 0x40, 0x2c, 0xf8, 0xdf, 0x28, 0xd1,
#   0xfd, 0xfb, 0x1a, 0x00, 0x23, 0x06, 0x1d, 0x01, 0x42, 0x36, 0xf1, 0x08,
#   0x13, 0x20, 0xf5, 0xff, 0xf7, 0x00, 0xfc, 0x08, 0xf7, 0xfd, 0x06, 0x27,
#   0xfd, 0x14, 0x12, 0x08, 0xf7, 0xf6, 0x3a, 0x13, 0x10, 0x8d, 0x57, 0x02,
#   0x1f, 0xf8, 0x21, 0xf0, 0x59, 0x16, 0x19, 0xf2, 0x14, 0x2e, 0xee, 0x14,
#   0xe5, 0x09, 0xe8, 0x2f, 0x1c, 0xb5, 0xdf, 0x5b, 0x15, 0x22, 0xe3, 0xd3,
#   0xef, 0x0b, 0x3a, 0x1c, 0xd1, 0xcf, 0x42, 0xea, 0x35, 0xe6, 0xee, 0x03,
#   0x2b, 0xfd, 0xf1, 0xdd, 0xfc, 0xf1, 0x00, 0xff, 0xe2, 0xe5, 0xc3, 0xfa,
#   0x0f, 0xe3, 0xcc, 0x1a, 0xec, 0x02, 0xfc, 0xf6, 0x0a, 0xdd, 0x06, 0x08,
#   0x13, 0xf2, 0x4b, 0x06, 0x42, 0xfb, 0x40, 0xd0, 0x3b, 0x4d, 0xde, 0xf3,
#   0xfe, 0x4d, 0x0a, 0xf3, 0xcd, 0x0c, 0x02, 0x35, 0xef, 0xc8, 0xd1, 0x2e,
#   0x1b, 0xf8, 0xdd, 0xfe, 0xe0, 0xef, 0x69, 0xee, 0x3d, 0xa8, 0x7f, 0xf5,
#   0x31, 0x06, 0x25, 0xd0, 0x53, 0x6e, 0xf7, 0xdc, 0x0b, 0x6a, 0x2d, 0xfb,
#   0xba, 0x31, 0x09, 0x57, 0xf9, 0xaa, 0xc3, 0x67, 0x31, 0x07, 0xaf, 0xbb,
#   0xe4, 0xf7, 0x6b, 0xde, 0x1a, 0xab, 0x35, 0x11, 0x29, 0xab, 0x09, 0xda,
#   0x40, 0xd8, 0x01, 0xf3, 0x18, 0xf1, 0x0b, 0xe2, 0x03, 0xbb, 0xb8, 0x27,
#   0xfb, 0xa8, 0xd9, 0x2a, 0x22, 0xf4, 0xb6, 0xe2, 0xce, 0xcc, 0x25, 0xe7,
#   0x22, 0xf3, 0x3d, 0xd8, 0x1e, 0x18, 0x15, 0xe8, 0x41, 0x3d, 0xff, 0x13,
#   0xeb, 0xe0, 0x07, 0xf6, 0xca, 0xff, 0x1e, 0xf8, 0xef, 0xd7, 0xe0, 0x04,
#   0x05, 0xef, 0xfd, 0xef, 0xd5, 0x06, 0x37, 0xd0, 0x13, 0xf7, 0x44, 0x03,
#   0x0f, 0xf3, 0xf6, 0x03, 0x46, 0x3d, 0x0d, 0xd8, 0xff, 0x2f, 0x20, 0x08,
#   0xc4, 0xde, 0x0b, 0x2e, 0x0b, 0xb4, 0xc2, 0x33, 0x05, 0x05, 0x03, 0xd7,
#   0xc8, 0xea, 0x24, 0xc4, 0x0c, 0x01, 0x1c, 0xff, 0x11, 0xac, 0x22, 0x0e,
#   0x14, 0xd4, 0x0c, 0x0c, 0xf5, 0x55, 0x03, 0xed, 0xd7, 0xb1, 0xcb, 0x1b,
#   0xf2, 0xc0, 0xe6, 0x23, 0xc5, 0x0b, 0xe3, 0xe6, 0xd1, 0xb9, 0x01, 0xdb,
#   0xdb, 0x16, 0xef, 0x22, 0xf0, 0xce, 0xec, 0x0f, 0xa7, 0x98, 0x07, 0x26,
#   0x26, 0x9b, 0xd5, 0x15, 0x3a, 0x2a, 0x0a, 0x04, 0xfd, 0x39, 0x10, 0xd9,
#   0x07, 0x35, 0x11, 0xfc, 0x3a, 0x3a, 0xdb, 0x12, 0xd0, 0x23, 0xb5, 0x1a,
#   0xe3, 0xd8, 0x19, 0x26, 0xa7, 0xa3, 0xf8, 0x37, 0x27, 0xb9, 0xa9, 0xeb,
#   0x29, 0x2f, 0x12, 0xc0, 0x1d, 0x3d, 0x55, 0xb8, 0xf7, 0xd1, 0xf3, 0x32,
#   0x4c, 0x38, 0xba, 0x36, 0xf1, 0x23, 0xdd, 0x0c, 0xc8, 0xf5, 0xc5, 0x17,
#   0xd6, 0xf3, 0xec, 0x22, 0x44, 0xcf, 0x07, 0xd8, 0x12, 0xec, 0x0a, 0xdd,
#   0x34, 0x3b, 0xf4, 0xdd, 0xf8, 0xc9, 0x0d, 0xe2, 0x42, 0xe5, 0xd1, 0xfc,
#   0xc2, 0x23, 0xbb, 0x0f, 0xb6, 0x13, 0xcf, 0x0d, 0xa7, 0x81, 0xf4, 0x35,
#   0xf5, 0xad, 0x01, 0x03, 0x62, 0x0d, 0x19, 0xcb, 0x0b, 0x38, 0x44, 0xce,
#   0xda, 0xfc, 0x23, 0x04, 0x45, 0x3e, 0xc1, 0x46, 0xa9, 0x26, 0x88, 0x48,
#   0xcf, 0xff, 0x18, 0x1a, 0x84, 0xa7, 0xe4, 0x66, 0x36, 0x96, 0xdc, 0xfa,
#   0x55, 0xd0, 0xf8, 0x88, 0x0d, 0x58, 0x75, 0x96, 0xef, 0xee, 0x54, 0x16,
#   0x6c, 0x35, 0xab, 0x29, 0xd6, 0x0b, 0xb0, 0x02, 0xc4, 0xe7, 0xe4, 0xeb,
#   0xca, 0xd3, 0xd8, 0x2f, 0xf6, 0xb7, 0x17, 0xe0, 0x53, 0x05, 0xf3, 0xbb,
#   0x25, 0x54, 0x23, 0xcd, 0xe6, 0xb9, 0x00, 0x16, 0x36, 0xed, 0xa4, 0x23,
#   0xd3, 0x0a, 0xe6, 0xf0, 0xd5, 0x0a, 0xff, 0xf9, 0xd3, 0xdc, 0x00, 0x27,
#   0xe4, 0xd7, 0xef, 0x02, 0x1d, 0x24, 0x3f, 0xf0, 0xe9, 0x40, 0x36, 0xe8,
#   0xf2, 0x05, 0x1e, 0x1d, 0x2f, 0x2f, 0xe6, 0xed, 0xea, 0x37, 0xb4, 0xb5,
#   0x9f, 0x24, 0x0c, 0xdf, 0xc2, 0xbd, 0xc2, 0x2c, 0xbe, 0xc8, 0x19, 0xf5,
#   0x16, 0x31, 0x32, 0xc6, 0xdd, 0x67, 0x3a, 0xd8, 0x0e, 0xbb, 0x2a, 0x2b,
#   0x47, 0x2a, 0xc0, 0x30, 0xdd, 0x31, 0xb2, 0xb5, 0x87, 0x1a, 0xdb, 0xf2,
#   0xd7, 0xdb, 0xae, 0x1c, 0xc5, 0xd9, 0x10, 0xf5, 0x2a, 0x19, 0x2f, 0xc3,
#   0xab, 0x55, 0xf4, 0xcb, 0xef, 0xc6, 0x0c, 0x01, 0x42, 0xf9, 0x9c, 0x14,
#   0x21, 0x17, 0xee, 0x30, 0x1a, 0x45, 0x09, 0x07, 0xf3, 0x0e, 0x06, 0xe9,
#   0x20, 0xf8, 0x21, 0x01, 0xee, 0xf8, 0x3c, 0x00, 0x1d, 0x1e, 0x07, 0xeb,
#   0x12, 0xf6, 0x01, 0x03, 0x1f, 0x32, 0xee, 0xfe, 0x18, 0x28, 0xee, 0x3e,
#   0xef, 0x57, 0xf8, 0x04, 0x01, 0x00, 0xe7, 0x0d, 0x20, 0x0c, 0x20, 0x01,
#   0xd8, 0x0b, 0x4c, 0xf2, 0x18, 0x29, 0xfa, 0xc0, 0x22, 0xe5, 0x09, 0x23,
#   0x23, 0x2e, 0xec, 0x08, 0x0e, 0x3a, 0xff, 0x0c, 0xe5, 0x12, 0xe0, 0xc3,
#   0x03, 0xf4, 0xb4, 0xef, 0x0f, 0x09, 0x15, 0xf5, 0x06, 0xe0, 0xff, 0xf1,
#   0x16, 0x2f, 0xe4, 0xf0, 0xf1, 0xa3, 0x27, 0xe6, 0x18, 0xfe, 0xf7, 0x04,
#   0x1e, 0xfd, 0xd3, 0x1f, 0xef, 0x61, 0xd1, 0x07, 0xe8, 0x03, 0xfb, 0xb9,
#   0x11, 0xe3, 0x18, 0xf8, 0xe9, 0x14, 0x38, 0xea, 0x05, 0x13, 0xe9, 0xba,
#   0xf7, 0x07, 0x04, 0x0c, 0xfe, 0x4b, 0xd8, 0xf5, 0x25, 0x1c, 0xbd, 0x52,
#   0xfa, 0x56, 0xe0, 0x03, 0xf2, 0x1d, 0xd3, 0xf1, 0x44, 0xfc, 0x2e, 0xe2,
#   0xdc, 0x25, 0x33, 0xc9, 0x0c, 0x05, 0xe5, 0xa1, 0x00, 0xc8, 0x00, 0x2c,
#   0x1e, 0x32, 0xbb, 0xe7, 0x22, 0x0f, 0xda, 0x16, 0xd4, 0x31, 0xdd, 0xeb,
#   0x02, 0x14, 0x9e, 0xe6, 0x12, 0x02, 0x19, 0xdc, 0xe8, 0xf0, 0x18, 0xb6,
#   0x35, 0x0e, 0xf9, 0xe4, 0x05, 0x81, 0x0b, 0xc7, 0x13, 0x29, 0xb7, 0xef,
#   0xea, 0x04, 0xbc, 0xf3, 0xe0, 0x2f, 0xed, 0xe3, 0xfe, 0xf6, 0xde, 0xec,
#   0xd4, 0xd8, 0x07, 0xe1, 0xee, 0x3f, 0x2c, 0xb4, 0xf7, 0x10, 0xf4, 0xb1,
#   0xe7, 0xc7, 0xd3, 0x09, 0x36, 0x22, 0xc6, 0xf6, 0x13, 0x04, 0x84, 0xe8,
#   0xa5, 0x4b, 0xf6, 0xdc, 0xfe, 0xfc, 0xac, 0xe4, 0xcd, 0xff, 0x2a, 0xf1,
#   0xcd, 0x28, 0x3c, 0xab, 0xf7, 0x1c, 0xee, 0xd7, 0xf0, 0xa7, 0xde, 0x09,
#   0x37, 0x46, 0xa5, 0xef, 0x02, 0x0c, 0xbf, 0xd5, 0xad, 0x14, 0xfb, 0xd7,
#   0x00, 0xf5, 0xac, 0xda, 0xd9, 0xf9, 0x0e, 0xb5, 0xf4, 0x05, 0xf9, 0x91,
#   0xf2, 0x2b, 0xe8, 0xea, 0xf1, 0xa6, 0xf9, 0xd3, 0x0e, 0x04, 0xae, 0xef,
#   0xf3, 0xf7, 0x2b, 0xda, 0x02, 0x00, 0x14, 0x17, 0xfe, 0x0e, 0x1a, 0x08,
#   0xf2, 0xf1, 0xf7, 0x09, 0xf0, 0x01, 0xf4, 0x22, 0xd1, 0x05, 0xf3, 0x19,
#   0x0a, 0x20, 0x18, 0x1b, 0xf6, 0xfe, 0x31, 0x27, 0x05, 0xf6, 0x24, 0xcf,
#   0x17, 0xe6, 0x0a, 0x15, 0x06, 0xf2, 0x38, 0xfb, 0xdf, 0xee, 0xf6, 0x0c,
#   0xdb, 0xef, 0xe1, 0x2c, 0xd1, 0xea, 0xee, 0x0c, 0x09, 0x32, 0x15, 0x15,
#   0xd8, 0xf2, 0x3d, 0x25, 0xfc, 0x0a, 0x11, 0xcb, 0x07, 0xdb, 0xf9, 0x17,
#   0x12, 0xf5, 0x1a, 0x08, 0xe0, 0x06, 0x00, 0x14, 0xec, 0xf4, 0xe7, 0x1b,
#   0xd5, 0xfa, 0xf5, 0x11, 0x07, 0x15, 0x19, 0x0a, 0xe3, 0xdb, 0x21, 0x14,
#   0xf6, 0xcb, 0x17, 0xd3, 0x02, 0xdd, 0xf8, 0x0e, 0x0d, 0xe7, 0x1a, 0xf5,
#   0xd3, 0xed, 0xdc, 0x19, 0x00, 0xe6, 0xd7, 0xff, 0xfa, 0xc6, 0xfd, 0x02,
#   0x15, 0x30, 0xfa, 0x2f, 0xe2, 0xe3, 0x12, 0x3a, 0xdf, 0xef, 0x37, 0xba,
#   0x1f, 0xc7, 0xcf, 0x17, 0x22, 0x91, 0x2f, 0xf8, 0xd3, 0xc9, 0xef, 0x29,
#   0xf4, 0xbd, 0xc1, 0x09, 0xde, 0xe6, 0xda, 0x15, 0x0b, 0x34, 0x25, 0x0f,
#   0xe9, 0xb6, 0x13, 0x3c, 0xfd, 0x26, 0x21, 0xb4, 0x0d, 0xbf, 0xe1, 0x0b,
#   0x1b, 0xdf, 0x17, 0x00, 0xb6, 0xfc, 0xfc, 0x13, 0xe7, 0xd1, 0xe2, 0x08,
#   0xd2, 0x18, 0xeb, 0x07, 0xf7, 0x1d, 0x20, 0xf0, 0x15, 0xb1, 0x21, 0x1e,
#   0xda, 0xb9, 0x06, 0xfa, 0xf1, 0xef, 0xd5, 0xf3, 0xea, 0xd5, 0xf6, 0xe0,
#   0xf4, 0xbe, 0xe1, 0xf9, 0xd0, 0x07, 0xb8, 0x04, 0xf1, 0xba, 0xe9, 0x0e,
#   0xf4, 0x25, 0xc6, 0x0a, 0xd5, 0xeb, 0x12, 0xf3, 0xe0, 0x90, 0x15, 0xd7,
#   0x08, 0x81, 0xc2, 0x3c, 0xe9, 0x8d, 0x21, 0x0e, 0xfd, 0xc0, 0xcc, 0x15,
#   0xf0, 0xcf, 0xaa, 0x1e, 0x0c, 0xb8, 0xef, 0xfc, 0x12, 0x01, 0xd3, 0x12,
#   0xaf, 0xb9, 0x1a, 0x23, 0xd7, 0xbf, 0x09, 0xe8, 0x01, 0xb2, 0xe4, 0x0e,
#   0xdb, 0xbe, 0x00, 0x04, 0xea, 0xdb, 0xe3, 0x23, 0xf9, 0xba, 0xb9, 0x10,
#   0xf2, 0xe5, 0xfe, 0xfe, 0xf1, 0xfb, 0x10, 0xd0, 0xd6, 0xc6, 0x07, 0x04,
#   0xd7, 0xfb, 0xd7, 0x22, 0x02, 0x0c, 0x0c, 0xff, 0xf5, 0x06, 0x02, 0xf5,
#   0xfa, 0xe2, 0xef, 0x06, 0x03, 0x2c, 0x0a, 0x0b, 0x16, 0xf4, 0xfb, 0x26,
#   0xd0, 0x21, 0xd6, 0x1c, 0x23, 0x14, 0xf1, 0x06, 0xea, 0xbe, 0x11, 0x1f,
#   0xf7, 0x04, 0x24, 0xfa, 0x06, 0xf8, 0x01, 0xf4, 0x2c, 0x06, 0xaf, 0xff,
#   0xd0, 0x4b, 0xfc, 0xef, 0x16, 0xb4, 0xe8, 0xf8, 0xa3, 0x33, 0x9c, 0xf8,
#   0x33, 0x29, 0xdd, 0x37, 0xf2, 0xa0, 0x10, 0x2b, 0x1d, 0xe8, 0x05, 0xf7,
#   0xce, 0x0d, 0x0b, 0xf9, 0x25, 0xf1, 0xc5, 0xd4, 0xef, 0x20, 0xbb, 0xfd,
#   0x3c, 0xdd, 0xf5, 0xea, 0xe5, 0x1f, 0xab, 0x03, 0x00, 0x00, 0xe9, 0xe9,
#   0xbf, 0xe7, 0xd7, 0x0a, 0x0f, 0x1e, 0x1c, 0x08, 0xc4, 0x15, 0x1a, 0xf9,
#   0x1b, 0xf4, 0xbf, 0x10, 0xd9, 0x34, 0x07, 0xe4, 0x39, 0xf6, 0x08, 0x00,
#   0xa3, 0x1f, 0xe4, 0xee, 0x03, 0x23, 0xe1, 0x09, 0xec, 0xad, 0xe8, 0x36,
#   0xf8, 0x18, 0x2a, 0x00, 0xd7, 0x0f, 0xfa, 0xf0, 0x56, 0xe7, 0xa8, 0x1d,
#   0xda, 0x3b, 0x07, 0xe0, 0x4c, 0xd9, 0xf8, 0x1c, 0xc8, 0x2a, 0xb9, 0x16,
#   0x27, 0x3f, 0xbc, 0x29, 0xc1, 0xe0, 0xf0, 0x17, 0x17, 0xf6, 0x10, 0x05,
#   0xb6, 0x09, 0x15, 0xf3, 0x18, 0xcf, 0xa9, 0x0f, 0xf7, 0x42, 0x07, 0xf6,
#   0x29, 0xf4, 0x0e, 0xf5, 0xf1, 0x1c, 0xbd, 0x07, 0x23, 0x30, 0xfd, 0x06,
#   0xe3, 0x11, 0xe6, 0xe6, 0xf3, 0x1d, 0x16, 0xfe, 0x81, 0x14, 0x1a, 0xe2,
#   0x04, 0xcf, 0xc0, 0x1c, 0xfe, 0x26, 0x18, 0x19, 0x19, 0x0f, 0xff, 0x2b,
#   0xcd, 0x1c, 0xe7, 0x06, 0x16, 0x2d, 0xd5, 0x17, 0xde, 0x0f, 0x0c, 0x15,
#   0x08, 0x2c, 0x1a, 0x08, 0xc3, 0x04, 0x01, 0xf5, 0x00, 0xc4, 0xcc, 0x1a,
#   0xee, 0x30, 0x1e, 0x06, 0x17, 0x0c, 0x07, 0x0e, 0xf0, 0x15, 0xe3, 0x07,
#   0x20, 0x2b, 0xd4, 0x22, 0xbc, 0x06, 0x04, 0xff, 0xfc, 0x24, 0x17, 0x08,
#   0xc8, 0x07, 0x0e, 0xf9, 0x02, 0xe4, 0xf8, 0x0c, 0x03, 0x33, 0x24, 0x0d,
#   0xfb, 0x17, 0xff, 0xf4, 0x09, 0x0e, 0xf2, 0x18, 0x20, 0x29, 0xeb, 0x0f,
#   0xf6, 0xf2, 0xe0, 0xf1, 0x01, 0xe9, 0x14, 0xec, 0xf4, 0xf2, 0xec, 0x35,
#   0xe6, 0xf5, 0x13, 0xd0, 0x26, 0xdc, 0xd8, 0xfd, 0xf5, 0x14, 0x3d, 0xfc,
#   0xe9, 0xfe, 0xf0, 0xc5, 0xd9, 0xed, 0xea, 0xf9, 0x0c, 0xdd, 0xf6, 0xd4,
#   0xfd, 0xd0, 0x24, 0xd2, 0xe9, 0xcc, 0xdc, 0x52, 0xdd, 0xe9, 0x07, 0xd8,
#   0x4f, 0xa3, 0xda, 0xed, 0xef, 0x2f, 0x49, 0x1d, 0xe1, 0xef, 0x26, 0xcd,
#   0xbe, 0xfd, 0xf2, 0xdf, 0x05, 0x13, 0x03, 0xea, 0xf6, 0xe4, 0xfc, 0xe6,
#   0x07, 0x06, 0xe7, 0x37, 0xf7, 0xed, 0x20, 0xe3, 0x2b, 0xe5, 0x03, 0x26,
#   0xde, 0x1e, 0x17, 0x0d, 0xe6, 0xfb, 0x22, 0xd3, 0xc5, 0xf9, 0xc9, 0xe1,
#   0xd8, 0xf2, 0xea, 0xf5, 0x11, 0xe1, 0x1a, 0xdd, 0x00, 0xe0, 0xe6, 0x61,
#   0xe4, 0xca, 0x26, 0xee, 0x2f, 0xe8, 0xee, 0x20, 0xd5, 0x0e, 0x63, 0x03,
#   0xcf, 0x08, 0xe7, 0xcc, 0xd4, 0x0c, 0xe5, 0xdc, 0xd7, 0x05, 0xf0, 0xb0,
#   0xe2, 0xe3, 0x45, 0xc4, 0xe8, 0xe8, 0xd7, 0x73, 0xb2, 0xbd, 0xf7, 0xe1,
#   0x7f, 0xc0, 0xe9, 0xff, 0xc6, 0x35, 0x7e, 0x2e, 0xc7, 0xed, 0x1f, 0xc2,
#   0xb8, 0x1a, 0xeb, 0xce, 0xfc, 0x14, 0xf9, 0xb8, 0x01, 0x05, 0x1d, 0xd8,
#   0xf6, 0xe0, 0xe5, 0x3d, 0xb8, 0xd1, 0x24, 0xd6, 0x4c, 0xc4, 0x0d, 0x2f,
#   0x89, 0x3c, 0x48, 0x1e, 0xce, 0xf9, 0x09, 0xd8, 0xb2, 0x1c, 0xde, 0xdf,
#   0xde, 0xf2, 0x01, 0xf2, 0xe2, 0xdb, 0x2b, 0xc7, 0xf2, 0xf7, 0xe5, 0x2c,
#   0xe5, 0xd8, 0x17, 0xd3, 0x37, 0xee, 0x0b, 0x0e, 0xe7, 0x2b, 0x26, 0x16,
#   0xce, 0x07, 0xef, 0xe2, 0xd9, 0x0b, 0xe5, 0xd8, 0xed, 0xf5, 0xec, 0xac,
#   0x02, 0xf6, 0x23, 0xbe, 0xe9, 0xf2, 0xe9, 0x29, 0x98, 0xed, 0x03, 0xac,
#   0x47, 0xd2, 0xd5, 0xe0, 0xbf, 0x3c, 0x59, 0x1d, 0xc2, 0xe3, 0xfd, 0xc3,
#   0xea, 0x07, 0xe1, 0xd8, 0x01, 0x0d, 0x06, 0xb4, 0x07, 0xe1, 0x13, 0xc6,
#   0xee, 0xef, 0xea, 0x18, 0xc6, 0xe3, 0x3d, 0xc0, 0x0a, 0xde, 0x07, 0x2d,
#   0xdb, 0x4d, 0x1c, 0x3d, 0x03, 0x02, 0x09, 0xda, 0xe4, 0x14, 0xfb, 0xe2,
#   0x09, 0xfa, 0xed, 0x01, 0x3c, 0xe3, 0x1f, 0x05, 0x33, 0x00, 0x12, 0x02,
#   0xf6, 0x2f, 0x11, 0x1b, 0xef, 0xed, 0xe9, 0x08, 0x0d, 0xfd, 0xfa, 0x04,
#   0x11, 0xdd, 0x0e, 0x26, 0xea, 0xfa, 0x35, 0xf2, 0x16, 0xf1, 0x66, 0xf6,
#   0x17, 0xb0, 0xe1, 0x20, 0x62, 0x02, 0x0f, 0xdf, 0xfe, 0x3e, 0x1c, 0x12,
#   0xda, 0xc2, 0xd6, 0x56, 0xe5, 0xdc, 0xc8, 0x28, 0x34, 0x17, 0x27, 0x03,
#   0xef, 0xce, 0x5c, 0xf4, 0x02, 0xf9, 0x1f, 0xe9, 0x0d, 0xcc, 0x11, 0x03,
#   0x5b, 0x1c, 0xe9, 0xf6, 0xe0, 0x22, 0xf6, 0x0c, 0x04, 0xba, 0xda, 0x07,
#   0xfa, 0xef, 0xf1, 0x30, 0x11, 0xe8, 0x34, 0xda, 0xe8, 0xe1, 0x58, 0x01,
#   0x36, 0x11, 0x33, 0xfb, 0x22, 0xe7, 0xf9, 0xe5, 0x36, 0x31, 0x08, 0xcf,
#   0xf3, 0x37, 0xfa, 0xe0, 0xbe, 0xd1, 0x09, 0x0c, 0xf0, 0xe2, 0xc9, 0xf8,
#   0x2a, 0xeb, 0xf5, 0x2d, 0xed, 0xd6, 0x68, 0xc1, 0x61, 0x1e, 0x59, 0xf9,
#   0x37, 0xc1, 0xce, 0x18, 0x68, 0x1a, 0x1b, 0xde, 0xfd, 0x58, 0x4b, 0xf4,
#   0xaf, 0xc8, 0xff, 0x41, 0xee, 0xfc, 0xb8, 0xe9, 0x4d, 0xfc, 0x24, 0x17,
#   0xf3, 0xa7, 0x60, 0xe5, 0x4b, 0x27, 0x26, 0xf2, 0x21, 0xb9, 0xed, 0xe8,
#   0x2a, 0x28, 0x0e, 0xf0, 0xff, 0x4e, 0x0c, 0xf3, 0xeb, 0xce, 0xce, 0x26,
#   0xf1, 0x0b, 0xe4, 0xfa, 0x2f, 0xd7, 0x1c, 0xd9, 0x03, 0xab, 0x5c, 0x09,
#   0x02, 0x0d, 0x2f, 0xe1, 0xfe, 0x0d, 0xe7, 0x33, 0x2c, 0x16, 0x1a, 0xdd,
#   0xe5, 0x19, 0x0e, 0xd6, 0xb3, 0xfc, 0x21, 0xf7, 0xe5, 0xf1, 0xb4, 0xd9,
#   0x15, 0x34, 0x1d, 0x13, 0x08, 0xdc, 0x1b, 0xc7, 0x42, 0x0f, 0x22, 0xf5,
#   0xf6, 0xec, 0xa8, 0x09, 0x41, 0x07, 0x21, 0xde, 0xd4, 0x4b, 0x20, 0xdd,
#   0xc5, 0xe6, 0xfd, 0x4b, 0xdb, 0xd5, 0xce, 0xe1, 0x14, 0x0e, 0x22, 0x06,
#   0xdb, 0xc8, 0x7f, 0xae, 0x35, 0x1f, 0x19, 0xf5, 0x08, 0xde, 0xee, 0xff,
#   0x4f, 0x40, 0x0a, 0x13, 0x99, 0x3c, 0x1c, 0xfa, 0xf9, 0xe4, 0x14, 0x19,
#   0xcb, 0xe6, 0xdc, 0xea, 0x25, 0xf9, 0x22, 0x01, 0xe9, 0xc9, 0x2b, 0xdf,
#   0xd6, 0x15, 0xfb, 0x10, 0xea, 0x02, 0xc9, 0x23, 0xb5, 0xb7, 0x0a, 0x27,
#   0x1a, 0xb8, 0xf8, 0x1a, 0x18, 0xe0, 0x19, 0x0e, 0x1f, 0xce, 0x18, 0xea,
#   0xd2, 0x27, 0xef, 0x1a, 0x48, 0x03, 0xe1, 0x28, 0xe6, 0x24, 0xc2, 0x29,
#   0x08, 0xfd, 0xfa, 0x1f, 0xa4, 0xac, 0xea, 0x07, 0x24, 0xd4, 0xdb, 0x0b,
#   0x1c, 0x30, 0x1a, 0xe0, 0x43, 0x30, 0x18, 0xa9, 0xf9, 0xee, 0xe8, 0x31,
#   0x5f, 0x16, 0xcf, 0x2f, 0xdb, 0xfa, 0xec, 0x1b, 0xea, 0xdf, 0xdf, 0xee,
#   0xd1, 0xce, 0xd9, 0x11, 0x2a, 0xe1, 0xe2, 0xd5, 0x1c, 0x11, 0x02, 0xcf,
#   0x0c, 0x1e, 0x10, 0xee, 0xf5, 0xd2, 0x03, 0xfe, 0x20, 0xe4, 0xd5, 0x25,
#   0xae, 0x1a, 0xbc, 0x0e, 0xb7, 0x21, 0xb0, 0x1d, 0x94, 0x9d, 0x09, 0x1e,
#   0x04, 0x81, 0xd2, 0x1e, 0x20, 0x23, 0x1b, 0xc7, 0x1a, 0x2f, 0x28, 0xc7,
#   0x99, 0x01, 0xf6, 0xf9, 0x25, 0x33, 0xd9, 0x04, 0xcd, 0x06, 0x88, 0x1a,
#   0xd4, 0x17, 0xe9, 0x37, 0xa5, 0xac, 0x04, 0x31, 0x25, 0x9f, 0xf9, 0xfd,
#   0x17, 0x0c, 0x08, 0xa5, 0x3f, 0x3e, 0x4f, 0x8c, 0xe4, 0x06, 0xfd, 0x1a,
#   0x51, 0x30, 0xb7, 0x3a, 0xe6, 0x16, 0xaf, 0x26, 0xd0, 0x1b, 0xef, 0x12,
#   0xc7, 0xe2, 0xfc, 0x12, 0x2c, 0xb9, 0x04, 0x07, 0x28, 0x28, 0x0e, 0xaf,
#   0x19, 0x3d, 0x07, 0xf2, 0xf2, 0xb0, 0xdd, 0xfc, 0x2f, 0x1e, 0xc8, 0x13,
#   0xde, 0x0a, 0xdc, 0xf7, 0xed, 0x16, 0xea, 0xef, 0xc4, 0xd2, 0xe0, 0x09,
#   0xf2, 0xd6, 0xe9, 0x14, 0xee, 0x20, 0x24, 0xea, 0xf9, 0x32, 0x1a, 0xea,
#   0xe5, 0x10, 0xed, 0xfe, 0x3b, 0x2b, 0xc9, 0x0d, 0xd4, 0x29, 0x91, 0xe0,
#   0xab, 0x33, 0x11, 0x0c, 0xb7, 0xe1, 0xc4, 0xff, 0xe8, 0xcb, 0xed, 0xfb,
#   0xe8, 0x42, 0x32, 0xa7, 0xf5, 0x38, 0x2d, 0xd4, 0xfc, 0xb5, 0x08, 0x2f,
#   0x50, 0x2e, 0xa8, 0x2c, 0xf9, 0x1d, 0xa0, 0xe5, 0xc8, 0x06, 0xf7, 0xe2,
#   0xd2, 0xf2, 0xad, 0xfa, 0xf0, 0xfb, 0x09, 0xf3, 0x0a, 0x31, 0x27, 0xc0,
#   0x00, 0x1e, 0xfc, 0xdf, 0xf4, 0xb6, 0xfd, 0xfd, 0x2d, 0x21, 0xc4, 0x08,
#   0xe2, 0xed, 0x33, 0xdd, 0x2b, 0x03, 0x23, 0x21, 0x07, 0x0a, 0x24, 0x14,
#   0x04, 0xf0, 0xe2, 0x07, 0xee, 0xf9, 0xfb, 0x2f, 0xfe, 0xfc, 0x15, 0x2c,
#   0x09, 0x3a, 0x00, 0x30, 0x01, 0xf9, 0x07, 0x19, 0x0a, 0xeb, 0x78, 0xb1,
#   0x22, 0xe6, 0x03, 0x1a, 0x14, 0xe7, 0x32, 0x10, 0xd5, 0x05, 0xe7, 0x2a,
#   0xe7, 0xed, 0xe8, 0x43, 0xd9, 0xdb, 0xf8, 0x2e, 0xfc, 0x51, 0xf7, 0x16,
#   0xfb, 0x04, 0x41, 0x16, 0xfc, 0x00, 0x23, 0xc2, 0x2f, 0xd7, 0xff, 0x19,
#   0x22, 0x01, 0x0a, 0x07, 0xec, 0x12, 0xed, 0xff, 0xca, 0xdb, 0xd6, 0x36,
#   0xd5, 0xf3, 0xf0, 0x1c, 0x01, 0x18, 0x0f, 0x0d, 0xf1, 0xe2, 0x3a, 0x03,
#   0xaf, 0xe0, 0x1c, 0xe3, 0x33, 0xdf, 0x0e, 0x2e, 0xf8, 0xfd, 0x1a, 0x1c,
#   0x04, 0xc6, 0xed, 0x32, 0x00, 0xd3, 0xd9, 0x12, 0xf1, 0xd9, 0x0a, 0x0a,
#   0xf0, 0x35, 0x02, 0x1a, 0xdf, 0xfd, 0x13, 0x37, 0xdd, 0xdb, 0x6b, 0xdc,
#   0x23, 0xa6, 0xd2, 0x13, 0x12, 0xad, 0x36, 0x00, 0xdc, 0xd0, 0xeb, 0x20,
#   0x06, 0xcd, 0xa9, 0x1d, 0xf3, 0xd3, 0xee, 0x33, 0xfc, 0x35, 0x09, 0xfc,
#   0xd9, 0xbc, 0x31, 0x4e, 0xf8, 0x1c, 0x22, 0xc3, 0x0e, 0xa6, 0xe7, 0xf1,
#   0x08, 0xee, 0x11, 0x05, 0xec, 0xdc, 0xf6, 0x0b, 0x02, 0xb6, 0xcb, 0x0e,
#   0xe8, 0xef, 0xfd, 0x11, 0x01, 0x02, 0x2e, 0x07, 0xdf, 0xab, 0x3a, 0x14,
#   0xda, 0xb5, 0x07, 0xed, 0x02, 0xcc, 0xd9, 0xec, 0xd8, 0xc6, 0x0e, 0xea,
#   0xfc, 0xa7, 0xc5, 0x31, 0xfa, 0xdd, 0x95, 0x0f, 0x00, 0xb4, 0xf0, 0x04,
#   0xe9, 0x2d, 0xc7, 0x08, 0xbe, 0xdc, 0xe7, 0x09, 0x05, 0x8f, 0x3a, 0xea,
#   0xfb, 0x81, 0xc4, 0x21, 0xf1, 0x98, 0x16, 0xe9, 0x02, 0xc3, 0xc9, 0x2f,
#   0xf6, 0xb8, 0xa4, 0x24, 0x01, 0xb7, 0xeb, 0x26, 0xf5, 0x07, 0xeb, 0x0c,
#   0xa3, 0xb5, 0x18, 0xf9, 0xe5, 0xb8, 0x07, 0xe4, 0x02, 0xb2, 0xd5, 0x0a,
#   0x01, 0xb3, 0xf5, 0x00, 0xef, 0xaf, 0xe1, 0x07, 0x00, 0xaa, 0xab, 0x03,
#   0xf4, 0xd6, 0x03, 0xfd, 0xf8, 0x00, 0xf6, 0xc8, 0xda, 0xba, 0x19, 0xf9,
#   0xf6, 0xf6, 0x00, 0x12, 0x0c, 0xcb, 0xc8, 0x09, 0x12, 0xf6, 0xf1, 0xe7,
#   0x0b, 0x0e, 0x03, 0xe3, 0xcb, 0xf7, 0x12, 0xec, 0x0d, 0xd9, 0xdb, 0xef,
#   0x3f, 0xfd, 0xec, 0x3e, 0xf8, 0xc3, 0x05, 0xe9, 0x1c, 0x66, 0xd1, 0x2e,
#   0x0a, 0xff, 0xba, 0x1a, 0x06, 0x02, 0x0c, 0xdb, 0x37, 0x13, 0x3c, 0xe2,
#   0xda, 0x1c, 0x1d, 0x06, 0x08, 0xf0, 0xcd, 0xd2, 0x30, 0xf6, 0xff, 0x34,
#   0x2b, 0xd8, 0x1d, 0xf7, 0x04, 0x27, 0xfb, 0x0a, 0xf8, 0x10, 0xe5, 0x00,
#   0x20, 0xf2, 0xcf, 0xfd, 0x05, 0x19, 0x11, 0xe9, 0x08, 0xff, 0x25, 0xf8,
#   0x17, 0x05, 0x06, 0xdc, 0x0d, 0xd2, 0x0c, 0x22, 0x1c, 0xfc, 0xfb, 0xe7,
#   0x48, 0x3a, 0xc2, 0xb8, 0xcc, 0x2f, 0xb2, 0x26, 0x18, 0xf8, 0xf3, 0xe3,
#   0xab, 0x2a, 0x23, 0x11, 0xca, 0xeb, 0x22, 0xd3, 0xcc, 0x0b, 0xd3, 0xb2,
#   0x34, 0xe0, 0x2b, 0x33, 0x37, 0xe0, 0xfa, 0x15, 0x39, 0x6a, 0xc1, 0xf7,
#   0xed, 0x3a, 0xa7, 0x2d, 0x03, 0xff, 0x02, 0xea, 0xed, 0x17, 0x2b, 0xea,
#   0xb9, 0x09, 0x42, 0xe6, 0xd4, 0x25, 0xb7, 0x8c, 0x5b, 0xae, 0x31, 0x34,
#   0x2a, 0x17, 0x13, 0x17, 0x33, 0x37, 0x08, 0xfd, 0xfa, 0x12, 0xcf, 0xfe,
#   0x1d, 0xf1, 0xc8, 0xdd, 0x05, 0x15, 0x19, 0xf7, 0x08, 0x11, 0xfa, 0xca,
#   0xef, 0xfb, 0xf4, 0xdb, 0x5f, 0xb8, 0x2f, 0x5d, 0x35, 0x06, 0x0c, 0xea,
#   0x0a, 0xdb, 0x09, 0xf8, 0xfa, 0x00, 0xc0, 0x17, 0x1f, 0xfd, 0x05, 0xc7,
#   0xf6, 0x06, 0xf5, 0x14, 0xc8, 0xed, 0xf2, 0x13, 0xf5, 0xdf, 0xc4, 0x03,
#   0x21, 0x04, 0x06, 0x2a, 0x07, 0xe7, 0x09, 0x10, 0xf9, 0x41, 0xe6, 0x0c,
#   0xef, 0x20, 0xdc, 0x27, 0x0e, 0x0b, 0x00, 0xda, 0xc6, 0x2b, 0x1c, 0x0f,
#   0xc3, 0x0a, 0x23, 0x0b, 0xd3, 0xe2, 0xcb, 0xd3, 0x3c, 0xfe, 0x1a, 0x30,
#   0x41, 0x01, 0x1a, 0x07, 0x19, 0x36, 0xde, 0xb2, 0xc4, 0x1a, 0xe4, 0xd1,
#   0x10, 0xea, 0xc2, 0xe8, 0x81, 0xfb, 0x28, 0x03, 0xfc, 0xee, 0x04, 0xe4,
#   0xa9, 0x25, 0xf9, 0xe1, 0x34, 0xad, 0x21, 0x43, 0x0c, 0x09, 0xf5, 0xf9,
#   0xe2, 0x10, 0xd0, 0x0f, 0xdc, 0xea, 0xe7, 0x2b, 0xce, 0xae, 0xff, 0x21,
#   0x0d, 0xcc, 0xfb, 0x02, 0x3a, 0xce, 0xdc, 0x0f, 0x07, 0x59, 0x17, 0xd4,
#   0xda, 0x05, 0x23, 0x0c, 0x30, 0xeb, 0xb9, 0x27, 0xe2, 0x1c, 0xae, 0x17,
#   0xf4, 0xd5, 0x09, 0x2f, 0xa8, 0xb0, 0x06, 0x2d, 0x02, 0xbf, 0xb3, 0xfa,
#   0x09, 0xf6, 0xf9, 0xee, 0x06, 0x20, 0x45, 0xc7, 0xe6, 0xea, 0x1a, 0x15,
#   0x5d, 0x0c, 0xe2, 0x32, 0x04, 0x06, 0xef, 0x17, 0xd4, 0xed, 0xe1, 0x05,
#   0xcb, 0xd0, 0xe8, 0xfb, 0x0c, 0xc3, 0xef, 0xed, 0x30, 0xe4, 0x08, 0xe2,
#   0x19, 0x43, 0xf3, 0xff, 0xf6, 0xe3, 0x1f, 0xe9, 0x16, 0xdf, 0xcd, 0x10,
#   0xe7, 0x12, 0xdb, 0xf5, 0xc7, 0xe8, 0xd9, 0x29, 0xd0, 0xa7, 0xf0, 0x55,
#   0xfe, 0xe4, 0x04, 0x38, 0x42, 0x00, 0x15, 0xd9, 0xfe, 0x5c, 0x36, 0xc7,
#   0x10, 0x0c, 0x2f, 0x0d, 0x32, 0x11, 0xda, 0x23, 0xd9, 0x3a, 0x9a, 0x0f,
#   0xc3, 0x06, 0xfd, 0x08, 0x9d, 0x9f, 0xed, 0x47, 0xef, 0xad, 0xb1, 0xf7,
#   0x3e, 0xfd, 0xf9, 0xa9, 0xe7, 0x69, 0x57, 0xb1, 0xfc, 0xf0, 0x52, 0x0c,
#   0x43, 0x09, 0xcf, 0x46, 0xf8, 0x36, 0xcf, 0x04, 0xb2, 0xf8, 0xdc, 0xef,
#   0xc6, 0xbc, 0xd7, 0x07, 0xf0, 0xcb, 0x21, 0xf7, 0x49, 0xfe, 0x03, 0xd3,
#   0xfa, 0x55, 0x17, 0xdf, 0xf3, 0xe4, 0x34, 0xfa, 0x28, 0x14, 0xcd, 0x2e,
#   0xed, 0x37, 0xfa, 0xe8, 0xec, 0xf6, 0xff, 0x0b, 0xef, 0xd9, 0x00, 0x37,
#   0xfa, 0xed, 0x02, 0xff, 0x34, 0xf8, 0x15, 0xfc, 0xdf, 0x7f, 0x22, 0xef,
#   0x29, 0xfb, 0x3e, 0x29, 0x35, 0x13, 0xf6, 0x32, 0xf6, 0x3b, 0xd1, 0xbb,
#   0xc3, 0xf7, 0x16, 0x1d, 0xc6, 0xb3, 0x1c, 0x2d, 0xad, 0xb5, 0xfe, 0x21,
#   0x1c, 0x1e, 0x1c, 0xfe, 0xc0, 0x4a, 0x2b, 0xe5, 0x04, 0xf5, 0x1d, 0x24,
#   0x58, 0xf8, 0x0c, 0x36, 0xd1, 0x3e, 0xbd, 0xb1, 0xae, 0x05, 0xdb, 0xfd,
#   0xe1, 0xe5, 0xba, 0x08, 0xc5, 0xdf, 0x20, 0x19, 0x30, 0xf3, 0x2f, 0xe1,
#   0xba, 0x57, 0xf7, 0xd2, 0xf7, 0xdb, 0x57, 0xf8, 0x27, 0x10, 0xe8, 0x1f,
#   0x2a, 0xf1, 0xf5, 0x14, 0xfc, 0xc9, 0xff, 0xf1, 0x32, 0x18, 0xcc, 0x29,
#   0xe3, 0x44, 0x2e, 0xc6, 0x22, 0xd4, 0xfb, 0xe1, 0xee, 0x06, 0x1e, 0xf4,
#   0x39, 0xe1, 0xfb, 0xf5, 0xd8, 0xe5, 0x03, 0x8f, 0x25, 0x09, 0xee, 0x21,
#   0x04, 0xe3, 0x1c, 0xd8, 0x1e, 0x1b, 0xcc, 0x2a, 0x05, 0x43, 0x3c, 0xb8,
#   0x4b, 0xc1, 0xe7, 0x13, 0xd2, 0x0c, 0x2f, 0xec, 0x1a, 0xc1, 0x2a, 0xcd,
#   0xb4, 0xf3, 0xf9, 0x99, 0x1e, 0x0d, 0x08, 0x2c, 0x18, 0xe7, 0xf4, 0xdb,
#   0x0b, 0xf4, 0xe5, 0x28, 0x0b, 0x15, 0x0b, 0xc6, 0x0e, 0xbf, 0x09, 0x04,
#   0x15, 0x0f, 0xed, 0x15, 0x0f, 0xf1, 0x15, 0xea, 0xf5, 0xe5, 0x19, 0xad,
#   0x37, 0xf1, 0xda, 0xed, 0x15, 0x2a, 0x1f, 0xdb, 0x27, 0x2a, 0xe1, 0x6b,
#   0xcf, 0x28, 0x20, 0xb8, 0x2f, 0xc6, 0x11, 0x14, 0xc6, 0xef, 0x28, 0xcf,
#   0x1a, 0xe0, 0xe6, 0x03, 0xc9, 0x23, 0xbb, 0x9f, 0x47, 0x25, 0xfc, 0xc4,
#   0x16, 0x2f, 0xfb, 0xb7, 0x28, 0x48, 0xdb, 0x3b, 0xb8, 0x41, 0x6a, 0xbc,
#   0x55, 0xd8, 0x20, 0x3e, 0xa6, 0x13, 0x47, 0xfc, 0x1e, 0xd3, 0x18, 0xdf,
#   0xc6, 0x17, 0x0e, 0x9f, 0x21, 0x28, 0x33, 0x05, 0x12, 0x3a, 0xe8, 0xda,
#   0x19, 0x0f, 0xb3, 0x43, 0xe4, 0x20, 0x45, 0xb6, 0x44, 0xca, 0x13, 0x38,
#   0xbf, 0x10, 0xd4, 0xec, 0x22, 0xb8, 0x26, 0xd6, 0xec, 0x07, 0xf2, 0xaf,
#   0x10, 0xfb, 0xf1, 0xe8, 0x0c, 0x50, 0xdd, 0xd1, 0xfb, 0xf6, 0xde, 0x4b,
#   0xed, 0xde, 0x28, 0xcc, 0x20, 0xe0, 0x10, 0xf7, 0xe5, 0x14, 0x21, 0xe0,
#   0x04, 0x00, 0xf6, 0xfa, 0xd1, 0x1d, 0xdf, 0xcc, 0x0f, 0x2d, 0xd3, 0xe5,
#   0xd4, 0x24, 0xf2, 0x9f, 0x15, 0x15, 0x87, 0x33, 0xb7, 0x04, 0x3e, 0x9e,
#   0x2a, 0xe5, 0x20, 0xe6, 0xc8, 0x30, 0x54, 0xf3, 0x16, 0xb6, 0xfe, 0xdc,
#   0xdc, 0xf7, 0xc1, 0x93, 0x2d, 0x0c, 0x0b, 0xe4, 0xf0, 0x0d, 0xfe, 0xa0,
#   0x26, 0x04, 0xa9, 0x1c, 0xab, 0xf1, 0x46, 0x81, 0x04, 0xf2, 0xff, 0xdf,
#   0xd9, 0x35, 0x12, 0xfc, 0xf0, 0xaf, 0x0d, 0xb2, 0xca, 0xff, 0x0b, 0xb5,
#   0x13, 0xd8, 0x0c, 0x07, 0x0c, 0x0e, 0x0c, 0xed, 0x25, 0x0c, 0x2a, 0xff,
#   0x14, 0x2b, 0xfa, 0x00, 0xfc, 0xf1, 0x08, 0x11, 0x06, 0xe5, 0xf1, 0x0d,
#   0xfe, 0x01, 0xc1, 0xec, 0x03, 0x18, 0xf3, 0xf4, 0x02, 0xbc, 0x34, 0x18,
#   0x0b, 0xff, 0x1b, 0xce, 0x39, 0x4f, 0x0f, 0xe5, 0x12, 0x2d, 0x18, 0xdc,
#   0xf6, 0x0b, 0x16, 0x0e, 0x09, 0xc3, 0xe0, 0x31, 0x00, 0xee, 0xcb, 0xc2,
#   0xdd, 0x06, 0x06, 0xdb, 0xff, 0xb6, 0x2b, 0x13, 0xf6, 0xf4, 0xe7, 0xe1,
#   0x07, 0x0f, 0xe5, 0xdb, 0x1a, 0x17, 0xf5, 0xcf, 0xf7, 0xfc, 0xef, 0x01,
#   0x0a, 0xb1, 0xdb, 0x0c, 0x1f, 0xde, 0xaa, 0xe4, 0xef, 0xeb, 0x1a, 0xc9,
#   0x12, 0xec, 0x30, 0x10, 0x37, 0x05, 0x2c, 0xea, 0x2f, 0x36, 0x13, 0xf1,
#   0x08, 0x45, 0x14, 0xea, 0xf4, 0x03, 0x14, 0x15, 0x02, 0xcb, 0xdf, 0x1d,
#   0x1b, 0x06, 0xdf, 0xf9, 0xe4, 0x2d, 0x22, 0xee, 0x49, 0xd9, 0x44, 0xff,
#   0x2e, 0x34, 0x1e, 0xd3, 0x41, 0x7f, 0x0b, 0xce, 0x00, 0x55, 0x4a, 0xf2,
#   0xc2, 0x0c, 0x15, 0x2b, 0x04, 0xb2, 0xd6, 0x49, 0x03, 0xfd, 0xc8, 0xd7,
#   0xe9, 0x0b, 0x3a, 0xe7, 0x21, 0xae, 0x17, 0x0b, 0x36, 0x16, 0x40, 0xec,
#   0x1c, 0x28, 0x0a, 0xea, 0x1c, 0x21, 0x1e, 0xea, 0xfd, 0x03, 0xd6, 0x20,
#   0x04, 0xb3, 0xea, 0x27, 0xf9, 0xfc, 0xd7, 0xd9, 0xeb, 0x08, 0x09, 0xe3,
#   0xfd, 0xf4, 0x26, 0xde, 0x11, 0x1f, 0x2a, 0x02, 0x24, 0x26, 0x15, 0x01,
#   0xd6, 0x27, 0x11, 0x16, 0xe3, 0xf2, 0xfa, 0x19, 0xf3, 0xee, 0xf4, 0x10,
#   0x19, 0x19, 0xf6, 0xff, 0xd9, 0x0a, 0x17, 0xe7, 0x1f, 0xef, 0x36, 0xff,
#   0x0a, 0x00, 0x1c, 0xfb, 0x4c, 0x3f, 0x04, 0xf6, 0x04, 0x3b, 0x14, 0x07,
#   0xed, 0xf7, 0xfd, 0x18, 0x09, 0xdb, 0xe2, 0x50, 0x09, 0x02, 0xea, 0xd2,
#   0xe5, 0x0a, 0x22, 0xe7, 0xff, 0xf0, 0x22, 0x10, 0x04, 0xfd, 0x15, 0x08,
#   0x1e, 0x3b, 0x13, 0x0c, 0x08, 0x16, 0xf6, 0x0b, 0xf6, 0x08, 0xff, 0x26,
#   0x05, 0xc6, 0x04, 0x1c, 0xea, 0x0b, 0xe3, 0xef, 0xf3, 0x01, 0x13, 0xe8,
#   0xe6, 0xe4, 0xdb, 0x08, 0xe4, 0xfc, 0x38, 0x11, 0x1f, 0x2d, 0xf9, 0x52,
#   0xe7, 0x23, 0xcf, 0xfd, 0x38, 0x07, 0xf3, 0xd7, 0xf5, 0xe8, 0x54, 0x3a,
#   0xa6, 0xe7, 0xed, 0x99, 0xda, 0x0f, 0xd3, 0x07, 0x09, 0xab, 0x06, 0xfa,
#   0x09, 0xd1, 0x5e, 0xc0, 0x1d, 0x0b, 0xfb, 0x1c, 0xe8, 0x13, 0xb2, 0x02,
#   0x4f, 0xea, 0xcc, 0xe7, 0xe8, 0xde, 0x5f, 0x6f, 0xd8, 0xf8, 0xe0, 0xa0,
#   0xc3, 0x25, 0xdd, 0xec, 0x0a, 0xf5, 0x0a, 0x00, 0x1e, 0xdc, 0x14, 0xe8,
#   0x00, 0x1b, 0xf0, 0x18, 0x19, 0x0a, 0xfa, 0xe8, 0x3b, 0x07, 0x0c, 0x01,
#   0xf2, 0x36, 0x19, 0x16, 0xea, 0xf7, 0xff, 0x9f, 0xca, 0x36, 0xf0, 0xd7,
#   0xd0, 0xdd, 0xb4, 0x10, 0xde, 0xf2, 0x68, 0xd6, 0x07, 0x3b, 0xf1, 0x52,
#   0xd5, 0xed, 0xda, 0xf6, 0x56, 0x0d, 0xf0, 0xe2, 0xd3, 0x00, 0x67, 0x5d,
#   0xa0, 0x0d, 0xd5, 0xab, 0xe0, 0x2f, 0xe3, 0x04, 0xdf, 0xb5, 0x07, 0xcf,
#   0x32, 0xb9, 0x72, 0xcf, 0x11, 0x21, 0x03, 0x4c, 0x9e, 0x17, 0xe4, 0x01,
#   0x7f, 0x01, 0xe0, 0xe3, 0xd2, 0x02, 0x7a, 0x66, 0x9a, 0x26, 0xcc, 0x8b,
#   0xae, 0x1d, 0xd6, 0xff, 0xe6, 0xbc, 0x1d, 0x03, 0x33, 0x04, 0x6c, 0xe3,
#   0x05, 0x28, 0x02, 0x4c, 0xf5, 0xcf, 0x2a, 0xea, 0x76, 0xcd, 0x0b, 0x1b,
#   0xe5, 0x32, 0x3d, 0x27, 0xc6, 0x1c, 0xe6, 0xb0, 0x9c, 0x3c, 0xf4, 0xeb,
#   0xdb, 0xe1, 0xf8, 0xeb, 0x1c, 0x15, 0x18, 0xfc, 0x0e, 0x20, 0xee, 0x1c,
#   0xd1, 0xec, 0xf0, 0xfe, 0x33, 0x00, 0xed, 0x03, 0x08, 0xfe, 0x2a, 0x0b,
#   0xb1, 0x0a, 0xdf, 0xd3, 0xf3, 0x22, 0xe3, 0xfd, 0xdb, 0xec, 0xf8, 0xc4,
#   0x02, 0xca, 0x60, 0xd1, 0x10, 0x19, 0x0c, 0x22, 0x9c, 0xfc, 0xc8, 0xfd,
#   0x42, 0xf8, 0xde, 0xf1, 0xe0, 0x19, 0x1b, 0x40, 0x98, 0x17, 0xea, 0x9a,
#   0xcd, 0x32, 0xe2, 0xfa, 0xd8, 0xf2, 0x24, 0xd1, 0x22, 0xfc, 0x13, 0xdc,
#   0xd7, 0x18, 0x0e, 0x4c, 0xf5, 0xd9, 0xf0, 0xf1, 0xfc, 0xdd, 0xf4, 0x25,
#   0xf5, 0x19, 0x1a, 0x32, 0xc9, 0x15, 0xeb, 0xda, 0xb8, 0x25, 0x0b, 0xd7,
#   0xf1, 0xea, 0x1c, 0xe0, 0x12, 0x02, 0x0f, 0x06, 0x0e, 0x10, 0x12, 0x0f,
#   0xf8, 0xf7, 0xfa, 0x08, 0xed, 0x03, 0x04, 0x1f, 0xf1, 0x00, 0xf5, 0x1f,
#   0x07, 0x15, 0x06, 0x19, 0xfd, 0xf6, 0x18, 0x17, 0xf0, 0xdb, 0x3c, 0xd0,
#   0x21, 0xf3, 0x11, 0x14, 0x12, 0xf9, 0x1f, 0x07, 0xf7, 0x09, 0xec, 0x09,
#   0xfb, 0x05, 0xf3, 0x18, 0xf6, 0xdb, 0xf7, 0x2b, 0x0d, 0x3d, 0xf6, 0x11,
#   0xf1, 0xfd, 0x24, 0x1b, 0x05, 0xf6, 0x16, 0xfb, 0x1d, 0xe5, 0x08, 0x06,
#   0x0b, 0xf2, 0x0f, 0x01, 0xfc, 0xfc, 0xf7, 0x06, 0xe8, 0xea, 0xe7, 0x2e,
#   0xfa, 0xfb, 0xe8, 0xff, 0x07, 0x17, 0x0b, 0x16, 0xef, 0xe2, 0x1d, 0x0f,
#   0xe7, 0xca, 0x07, 0xed, 0x17, 0xef, 0x22, 0x19, 0xfe, 0x2a, 0x2f, 0xfb,
#   0xf1, 0xf1, 0xe1, 0x0c, 0x13, 0xfa, 0xe9, 0x05, 0xf4, 0xd5, 0x0b, 0x30,
#   0xf6, 0x2f, 0xdf, 0x15, 0xf5, 0x11, 0x0b, 0x36, 0xe1, 0xb9, 0x2b, 0xd6,
#   0x16, 0xdc, 0x0b, 0x0b, 0x12, 0xf0, 0x26, 0x10, 0xf4, 0xf5, 0xf8, 0x30,
#   0xd9, 0xec, 0xd6, 0x04, 0xf1, 0xd6, 0xe9, 0x34, 0xfb, 0x2b, 0xcd, 0xf3,
#   0xef, 0xe1, 0x12, 0x3f, 0xee, 0xfc, 0x1a, 0xf0, 0x25, 0xd3, 0xfa, 0xfe,
#   0x10, 0xea, 0x19, 0x06, 0xf3, 0xeb, 0xf3, 0x0f, 0xee, 0xe3, 0xd7, 0x07,
#   0xf0, 0xef, 0x03, 0xfb, 0xfc, 0x34, 0xff, 0xfc, 0xf4, 0xc8, 0x09, 0x0c,
#   0xcc, 0xb7, 0x05, 0xf8, 0xfc, 0xfc, 0x0b, 0xed, 0xda, 0xfa, 0x19, 0xe9,
#   0xf9, 0xbd, 0xd2, 0x17, 0xfc, 0x08, 0xb2, 0x03, 0xfc, 0xca, 0x04, 0xfb,
#   0xcf, 0xfb, 0xd8, 0xe9, 0xbd, 0x0e, 0x07, 0x0b, 0xf2, 0x81, 0x1e, 0xe8,
#   0x0f, 0xb7, 0xd9, 0x2a, 0xe2, 0xa8, 0x23, 0xfa, 0xf4, 0xd3, 0xe1, 0x38,
#   0xfc, 0xe0, 0xad, 0x18, 0xfa, 0xaa, 0xf1, 0x0d, 0xe6, 0x20, 0xcd, 0xee,
# ...
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0x90, 0x4d, 0x64, 0x3c, 0x58, 0xcb, 0x3d, 0x3c,
#   0x85, 0xd5, 0x19, 0x3c, 0x9c, 0xe0, 0x32, 0x3c, 0xd5, 0x7d, 0x13, 0x3c,
#   0x06, 0x7b, 0x17, 0x3c, 0x1c, 0xd1, 0x3a, 0x3c, 0x4f, 0x1a, 0x13, 0x3c,
#   0xb8, 0x1e, 0x33, 0x3c, 0xc7, 0x06, 0x3d, 0x3c, 0x62, 0xaa, 0x02, 0x3c,
#   0x2d, 0x72, 0x46, 0x3c, 0xbc, 0x8b, 0x46, 0x3c, 0xd2, 0x26, 0x61, 0x3c,
#   0x1e, 0x4e, 0x34, 0x3c, 0xe8, 0xd3, 0x3c, 0x3c, 0xed, 0x37, 0x2f, 0x3c,
#   0x97, 0x72, 0x2f, 0x3c, 0x48, 0x6b, 0x3b, 0x3c, 0xc2, 0x06, 0x1e, 0x3c,
#   0xba, 0x39, 0x27, 0x3c, 0xdc, 0x9a, 0x6b, 0x3c, 0xad, 0x86, 0x30, 0x3c,
#   0xca, 0xe9, 0x64, 0x3c, 0xca, 0xee, 0x1e, 0x3c, 0x15, 0x85, 0x4d, 0x3c,
#   0xe0, 0xb1, 0x35, 0x3c, 0x56, 0x58, 0x41, 0x3c, 0xcc, 0xc0, 0x4c, 0x3c,
#   0xbe, 0xe9, 0x46, 0x3c, 0x54, 0x6d, 0x51, 0x3c, 0x79, 0xe3, 0x46, 0x3c,
#   0x38, 0x73, 0x22, 0x3c, 0x8d, 0x9f, 0x19, 0x3c, 0x0f, 0xc9, 0x22, 0x3c,
#   0x85, 0x64, 0x2f, 0x3c, 0x55, 0x77, 0x47, 0x3c, 0x7b, 0x74, 0x49, 0x3c,
#   0xbf, 0x31, 0x3b, 0x3c, 0x95, 0xbc, 0x37, 0x3c, 0xb4, 0xb6, 0x13, 0x3c,
#   0x78, 0xfd, 0x19, 0x3c, 0x73, 0x76, 0x34, 0x3c, 0x72, 0x85, 0x61, 0x3c,
#   0x81, 0xd1, 0x22, 0x3c, 0xef, 0xa9, 0x47, 0x3c, 0xd0, 0xca, 0x47, 0x3c,
#   0x8b, 0x80, 0x4c, 0x3c, 0xfa, 0x9b, 0x0e, 0x3c, 0x48, 0x7d, 0x43, 0x3c,
#   0x74, 0x7e, 0x6e, 0x3c, 0x88, 0xb4, 0x2f, 0x3c, 0x1e, 0xa8, 0x5c, 0x3c,
#   0xc3, 0x14, 0x1f, 0x3c, 0x2b, 0x8d, 0x2f, 0x3c, 0x86, 0xd8, 0x16, 0x3c,
#   0x4c, 0x1d, 0x4f, 0x3c, 0xe1, 0x1a, 0x37, 0x3c, 0x35, 0xf7, 0x14, 0x3c,
#   0x09, 0xe8, 0x44, 0x3c, 0x29, 0xfc, 0x29, 0x3c, 0xf1, 0x45, 0x38, 0x3c,
#   0xe5, 0xbd, 0x49, 0x3c, 0xd3, 0x79, 0x4f, 0x3c, 0x15, 0x00, 0x00, 0x00,
#   0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64,
#   0x5f, 0x32, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32, 0x44, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x2a, 0xf9, 0xff, 0xff,
#   0x14, 0x00, 0x00, 0x00, 0xa4, 0x01, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x02, 0x04, 0x02, 0x00, 0x00, 0x8c, 0xf8, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x08, 0x01, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x24, 0x41, 0xd4, 0x38,
#   0x59, 0x48, 0xd1, 0x38, 0xea, 0x32, 0xaa, 0x38, 0x75, 0x3a, 0xa7, 0x38,
#   0x50, 0xae, 0x92, 0x38, 0xa5, 0x9e, 0x88, 0x38, 0x80, 0x98, 0xa5, 0x38,
#   0x55, 0x4c, 0xb6, 0x38, 0x75, 0x9f, 0xcd, 0x38, 0xe9, 0x29, 0x98, 0x38,
#   0x6e, 0x64, 0xd4, 0x38, 0xcd, 0x13, 0xe6, 0x38, 0xf1, 0xae, 0xb5, 0x38,
#   0xca, 0x68, 0xbd, 0x38, 0x24, 0xc0, 0xdc, 0x38, 0xbd, 0xa6, 0x90, 0x38,
#   0x5d, 0x51, 0x09, 0x39, 0xf8, 0x27, 0xb3, 0x38, 0x1a, 0xc0, 0xa9, 0x38,
#   0xb7, 0xa6, 0xab, 0x38, 0x14, 0x3d, 0x9e, 0x38, 0x29, 0x57, 0xa2, 0x38,
#   0xc9, 0x7f, 0xd0, 0x38, 0xa4, 0xf3, 0xb1, 0x38, 0x0a, 0xa1, 0xe4, 0x38,
#   0xe4, 0xf6, 0xb4, 0x38, 0x02, 0x30, 0xa2, 0x38, 0x1b, 0xbf, 0xa6, 0x38,
#   0x8c, 0x1e, 0xf9, 0x38, 0xa9, 0x31, 0x92, 0x38, 0x08, 0xf4, 0xd6, 0x38,
#   0x32, 0x02, 0x2b, 0x38, 0x67, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65,
#   0x6c, 0x2f, 0x62, 0x61, 0x74, 0x63, 0x68, 0x5f, 0x6e, 0x6f, 0x72, 0x6d,
#   0x61, 0x6c, 0x69, 0x7a, 0x61, 0x74, 0x69, 0x6f, 0x6e, 0x5f, 0x31, 0x2f,
#   0x46, 0x75, 0x73, 0x65, 0x64, 0x42, 0x61, 0x74, 0x63, 0x68, 0x4e, 0x6f,
#   0x72, 0x6d, 0x56, 0x33, 0x3b, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x5f,
#   0x31, 0x2f, 0x62, 0x69, 0x61, 0x73, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c,
#   0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x5f, 0x31, 0x2f, 0x42, 0x69,
#   0x61, 0x73, 0x41, 0x64, 0x64, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x2f,
#   0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x5f, 0x31, 0x2f, 0x43, 0x6f, 0x6e,
#   0x76, 0x32, 0x44, 0x00, 0x01, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x4a, 0xfb, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00, 0xa8, 0x01, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0xb8, 0x01, 0x00, 0x00,
#   0xac, 0xfa, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x0c, 0x01, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x4b, 0x5f, 0x22, 0x3b, 0x4c, 0x19, 0x20, 0x3b,
#   0x41, 0x33, 0x02, 0x3b, 0x06, 0xdb, 0xff, 0x3a, 0x20, 0x6b, 0xe0, 0x3a,
#   0x68, 0x06, 0xd1, 0x3a, 0x8f, 0x5b, 0xfd, 0x3a, 0xbe, 0x74, 0x0b, 0x3b,
#   0x96, 0x4c, 0x1d, 0x3b, 0x98, 0xce, 0xe8, 0x3a, 0x4a, 0x7a, 0x22, 0x3b,
#   0xad, 0x01, 0x30, 0x3b, 0x57, 0xfc, 0x0a, 0x3b, 0x5f, 0xe5, 0x10, 0x3b,
#   0x25, 0xdf, 0x28, 0x3b, 0x2f, 0x50, 0xdd, 0x3a, 0xd8, 0x17, 0x52, 0x3b,
#   0x6a, 0x0d, 0x09, 0x3b, 0x6c, 0xdb, 0x01, 0x3b, 0xad, 0x4f, 0x03, 0x3b,
#   0xf7, 0x19, 0xf2, 0x3a, 0x91, 0x60, 0xf8, 0x3a, 0xde, 0x7f, 0x1f, 0x3b,
#   0x8c, 0x21, 0x08, 0x3b, 0x0c, 0xe6, 0x2e, 0x3b, 0x8b, 0x6f, 0x0a, 0x3b,
#   0xab, 0x24, 0xf8, 0x3a, 0x4c, 0x1e, 0xff, 0x3a, 0xcd, 0x92, 0x3e, 0x3b,
#   0x68, 0xac, 0xdf, 0x3a, 0xd1, 0x6f, 0x24, 0x3b, 0xd2, 0xd1, 0x82, 0x3a,
#   0x15, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x2f, 0x63, 0x6f,
#   0x6e, 0x76, 0x32, 0x64, 0x5f, 0x31, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32,
#   0x44, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x2a, 0xfd, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00, 0xe4, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02, 0x3c, 0x01, 0x00, 0x00,
#   0x8c, 0xfc, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x88, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0xd8, 0xa4, 0x63, 0x39, 0x3f, 0x53, 0x88, 0x39,
#   0x0f, 0x21, 0x81, 0x39, 0xf0, 0xf5, 0xfa, 0x38, 0x22, 0xda, 0x7b, 0x38,
#   0x77, 0x20, 0x7c, 0x39, 0x30, 0xa3, 0x38, 0x39, 0xd1, 0xee, 0xa6, 0x39,
#   0xef, 0xf0, 0x96, 0x39, 0x48, 0xfe, 0xab, 0x38, 0x48, 0x32, 0x8b, 0x38,
#   0xb6, 0xfa, 0xfc, 0x38, 0x9a, 0x8e, 0x68, 0x39, 0x19, 0x56, 0x8b, 0x38,
#   0x3c, 0x80, 0xf5, 0x38, 0x2a, 0xce, 0x46, 0x39, 0x5f, 0x00, 0x00, 0x00,
#   0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x2f, 0x62, 0x61, 0x74, 0x63, 0x68, 0x5f,
#   0x6e, 0x6f, 0x72, 0x6d, 0x61, 0x6c, 0x69, 0x7a, 0x61, 0x74, 0x69, 0x6f,
#   0x6e, 0x2f, 0x46, 0x75, 0x73, 0x65, 0x64, 0x42, 0x61, 0x74, 0x63, 0x68,
#   0x4e, 0x6f, 0x72, 0x6d, 0x56, 0x33, 0x3b, 0x63, 0x6f, 0x6e, 0x76, 0x32,
#   0x64, 0x2f, 0x62, 0x69, 0x61, 0x73, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c,
#   0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x42, 0x69, 0x61, 0x73,
#   0x41, 0x64, 0x64, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x2f, 0x63, 0x6f,
#   0x6e, 0x76, 0x32, 0x64, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32, 0x44, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x82, 0xfe, 0xff, 0xff,
#   0x14, 0x00, 0x00, 0x00, 0xe4, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x09, 0x54, 0x01, 0x00, 0x00, 0xe4, 0xfd, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x88, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0xd8, 0xa4, 0x63, 0x39, 0x3f, 0x53, 0x88, 0x39, 0x0f, 0x21, 0x81, 0x39,
#   0xf0, 0xf5, 0xfa, 0x38, 0x22, 0xda, 0x7b, 0x38, 0x77, 0x20, 0x7c, 0x39,
#   0x30, 0xa3, 0x38, 0x39, 0xd1, 0xee, 0xa6, 0x39, 0xef, 0xf0, 0x96, 0x39,
#   0x48, 0xfe, 0xab, 0x38, 0x48, 0x32, 0x8b, 0x38, 0xb6, 0xfa, 0xfc, 0x38,
#   0x9a, 0x8e, 0x68, 0x39, 0x19, 0x56, 0x8b, 0x38, 0x3c, 0x80, 0xf5, 0x38,
#   0x2a, 0xce, 0x46, 0x39, 0x75, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65,
#   0x6c, 0x2f, 0x61, 0x63, 0x74, 0x69, 0x76, 0x61, 0x74, 0x69, 0x6f, 0x6e,
#   0x2f, 0x52, 0x65, 0x6c, 0x75, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x2f,
#   0x62, 0x61, 0x74, 0x63, 0x68, 0x5f, 0x6e, 0x6f, 0x72, 0x6d, 0x61, 0x6c,
#   0x69, 0x7a, 0x61, 0x74, 0x69, 0x6f, 0x6e, 0x2f, 0x46, 0x75, 0x73, 0x65,
#   0x64, 0x42, 0x61, 0x74, 0x63, 0x68, 0x4e, 0x6f, 0x72, 0x6d, 0x56, 0x33,
#   0x3b, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x62, 0x69, 0x61, 0x73,
#   0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32,
#   0x64, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x3b, 0x6d, 0x6f,
#   0x64, 0x65, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x43,
#   0x6f, 0x6e, 0x76, 0x32, 0x44, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x14, 0x00,
#   0x13, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0e, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x02, 0x48, 0x00, 0x00, 0x00, 0x04, 0x00, 0x04, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x35, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65,
#   0x6c, 0x2f, 0x67, 0x6c, 0x6f, 0x62, 0x61, 0x6c, 0x5f, 0x61, 0x76, 0x65,
#   0x72, 0x61, 0x67, 0x65, 0x5f, 0x70, 0x6f, 0x6f, 0x6c, 0x69, 0x6e, 0x67,
#   0x32, 0x64, 0x2f, 0x4d, 0x65, 0x61, 0x6e, 0x2f, 0x72, 0x65, 0x64, 0x75,
#   0x63, 0x74, 0x69, 0x6f, 0x6e, 0x5f, 0x69, 0x6e, 0x64, 0x69, 0x63, 0x65,
#   0x73, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x1c, 0x00, 0x18, 0x00, 0x17, 0x00, 0x10, 0x00, 0x0c, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00, 0x54, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x68, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x20, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x80, 0x3f, 0x19, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x72, 0x76, 0x69, 0x6e, 0x67, 0x5f, 0x64, 0x65, 0x66, 0x61,
#   0x75, 0x6c, 0x74, 0x5f, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x5f, 0x31, 0x3a,
#   0x30, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x4c, 0x00, 0x00, 0x00, 0x2c, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xd0, 0xff, 0xff, 0xff,
#   0x19, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x19,
#   0xe0, 0xff, 0xff, 0xff, 0x09, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x09, 0xf0, 0xff, 0xff, 0xff, 0x28, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x28, 0x0c, 0x00, 0x10, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x03
# };
# unsigned int g_hindi_alphabets_model_data_len = 30360;

# %% [markdown]
# To download your model for use at a later date:
#
# 1. On the left of the UI click on the folder icon
# 2. Click on the three dots to the right of the ```.cc``` file you just generated and select "download." The file can be found at ```models/{TFL_CC_MODEL_FILENAME}``` which by default is ```models/hindi_alphabets.cc```
#
# Next we'll deploy that model using the Arduino IDE.

# %%
# mount your drive to copy the data from google colab to your own google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!cp -r "colab-path" "drive-path"
# !cp -r  "/content/models" "/content/drive/MyDrive/hindi_data"

# %%
# !cp -r  "/content/hindi_alphabets_dataset" "/content/drive/MyDrive/hindi_data"
